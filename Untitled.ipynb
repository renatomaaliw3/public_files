# %% [markdown]
# # Data Visualization (Pandas)

# %%
# Data Visualization
# 1. Pandas
# 2. MatplotLib
# 3. Seaborn

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Data

df = pd.DataFrame(np.random.randn(500), index = pd.date_range('2019-01-01', periods = 500), columns = ['values'])
df
# Out:
#               values
# 2019-01-01  0.208863
# 2019-01-02  0.176974
# 2019-01-03 -0.963123
# 2019-01-04 -0.920075
# 2019-01-05 -1.495314
# ...              ...
# 2020-05-10 -1.428645
# 2020-05-11  0.432400
# 2020-05-12 -0.584901
# 2020-05-13 -0.313030
# 2020-05-14  0.048401
#
# [500 rows x 1 columns]

# %% [markdown]
# ### Line Plot

# %%
df.plot()

# %%
# Figure Size

df.plot(figsize = 15,8)) # tuple

# %%
# Another data set (Iris Dataset)

iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.plot(figsize = (10,5), title = 'Iris Dataset')

# %% [markdown]
# ## Data Visualization (Pandas - Bar Plot)

# %%
c_data = iris.drop(['species'], axis = 1)
c_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
c_data.iloc[3].plot(kind = 'bar', title = 'First Sample')

# %%
c_data.iloc[121].plot(kind = 'barh', title = 'First Sample')

# %% [markdown]
# ## Data Visualization (Pandas - Stacked Plot)

# %%
# Data
np.random.seed(10)

df2 = pd.DataFrame(np.random.randn(10,4), columns = ['a','b','c','d'])
df2
# Out:
#           a         b         c         d
# 0  1.331587  0.715279 -1.545400 -0.008384
# 1  0.621336 -0.720086  0.265512  0.108549
# 2  0.004291 -0.174600  0.433026  1.203037
# 3 -0.965066  1.028274  0.228630  0.445138
# 4 -1.136602  0.135137  1.484537 -1.079805
# 5 -1.977728 -1.743372  0.266070  2.384967
# 6  1.123691  1.672622  0.099149  1.397996
# 7 -0.271248  0.613204 -0.267317 -0.549309
# 8  0.132708 -0.476142  1.308473  0.195013
# 9  0.400210 -0.337632  1.256472 -0.731970

# %%
df2.plot(kind = 'bar', stacked = True, title = 'Samples')

# %% [markdown]
# ## Data Visualization (Histogram)
#
# - Distribution of Data

# %%
# Data

c_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
c_data.plot(kind = 'hist', title = 'Iris dataset', bins = 20)

# %%
c_data.plot(kind = 'hist', title = 'Iris dataset', bins = 20, stacked = True)

# %%
c_data.plot(kind = 'hist', title = 'Iris dataset', bins = 20, stacked = True, orientation = 'horizontal')

# %%
# Alternate Histogram (Additional knowledge)

c_data.hist(color = 'r')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000010691BC8>,
# ...
#       dtype=object)

# %% [markdown]
# # Data Visualization (Box Plot)

# %%
c_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
c_data.plot(kind = 'box', figsize = (16, 6))

# %%
c_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Orientation

c_data.plot(kind = 'box', figsize = (16, 6), vert = False)

# %% [markdown]
# # Data Visualization (Area Plot)

# %%
c_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
c_data.plot(kind = 'area', figsize = (10,5), title = 'Area Graph')

# %%
# Non-Stacked, Transparency

c_data.plot(kind = 'area', figsize = (10,5), title = 'Area Graph', stacked = False, alpha = 0.25)

# %% [markdown]
# # Data Visualization (Scatter Plot)

# %%
c_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
# x and y axis values

c_data.plot(x = 'sepal_width', y = 'petal_width', kind = 'scatter', title = 'Iris Data')

# %%
# with heat map

c_data.plot(x = 'sepal_width', y = 'petal_width', kind = 'scatter', title = 'Iris Data', c = 'petal_width')

# %%
# with heat map

c_data.plot(x = 'sepal_length', y = 'petal_length', kind = 'scatter', title = 'Iris Data', c = 'sepal_length')

# %%
# With Secondary Axis

ax = c_data.plot(kind = 'scatter', x = 'sepal_width', y = 'petal_width', label = 'width', color = 'y')
c_data.plot(kind = 'scatter', x = 'sepal_length', y = 'petal_length', label = 'length', ax = ax, color = 'k')

# %% [markdown]
# # Data Visualization (Pandas - Hex Plot)

# %%
c_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
c_data.plot(x = 'sepal_length', y = 'petal_width', gridsize = 20, kind = 'hexbin', C = 'sepal_width')

# %% [markdown]
# # Data Visualization (Pie)

# %%
c_data.iloc[0].plot(kind = 'pie', figsize = (10,5))

# %%
# Percentage Labels

c_data.iloc[0].plot(kind = 'pie', figsize = (10,5), autopct = '%.2f')

# %% [markdown]
# # Data Visualization (Scatter Matrix)

# %%
# import scatter matrix

from pandas.plotting import scatter_matrix

# %%
# Scatter Matrix

scatter_matrix(c_data, figsize = (10,5), diagonal = 'kde', color = 'b') # KDE is Kernel Density Estimate
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000012E54B48>,
# ...
#       dtype=object)

# %% [markdown]
# # Subplots

# %%
c_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
c_data.plot()

# %%
c_data.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000000133619C8>,
# ...
#       dtype=object)

# %%
# Subplotting

c_data.plot(subplots = True, layout = (2,2), figsize = (20,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000015D44408>,
# ...
#       dtype=object)
