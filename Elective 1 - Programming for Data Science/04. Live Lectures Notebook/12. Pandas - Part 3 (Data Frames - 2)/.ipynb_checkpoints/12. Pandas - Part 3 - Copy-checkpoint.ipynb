# %% [markdown]
# ## Resetting and Setting Index

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Using .reset_index()
#
#
#     - setting index into defaults

# %%
np.random.seed(100)

df = pd.DataFrame(np.random.randint(0,20,(5,5)), 'R1 R2 R3 R4 R5'.split(), 'C1 C2 C3 C4 C5'.split())
df
# Out:
#     C1  C2  C3  C4  C5
# R1   8   3   7  15  16
# R2  10   2   2   2  14
# R3   2  17  16  15   4
# R4  11  16   9   2  12
# R5   4   1  13  19   4

# %%
df.reset_index() # Something to remember this will not occur in place (not permanent)
# Out:
#   index  C1  C2  C3  C4  C5
# 0    R1   8   3   7  15  16
# 1    R2  10   2   2   2  14
# 2    R3   2  17  16  15   4
# 3    R4  11  16   9   2  12
# 4    R5   4   1  13  19   4

# %%
df
# Out:
#     C1  C2  C3  C4  C5
# R1   8   3   7  15  16
# R2  10   2   2   2  14
# R3   2  17  16  15   4
# R4  11  16   9   2  12
# R5   4   1  13  19   4

# %% [markdown]
# ### Using set_index()
#
#     - a method to set a List, Series or Data frame as index of a Data Frame.

# %%
df['new'] = 'A B C D E'.split()
df
# Out:
#     C1  C2  C3  C4  C5 new
# R1   8   3   7  15  16   A
# R2  10   2   2   2  14   B
# R3   2  17  16  15   4   C
# R4  11  16   9   2  12   D
# R5   4   1  13  19   4   E

# %%
# Use the set_index to set a specific column as the new index

df.set_index('new', inplace = True)

# %%
df
# Out:
#      C1  C2  C3  C4  C5
# new
# A     8   3   7  15  16
# B    10   2   2   2  14
# C     2  17  16  15   4
# D    11  16   9   2  12
# E     4   1  13  19   4

# %%
df
# Out:
#      C1  C2  C3  C4  C5
# new
# A     8   3   7  15  16
# B    10   2   2   2  14
# C     2  17  16  15   4
# D    11  16   9   2  12
# E     4   1  13  19   4

# %% [markdown]
# ## DataFrames with Multiple Index

# %% [markdown]
# ### Indexing and Selection of DataFrames with Multiple Indices
