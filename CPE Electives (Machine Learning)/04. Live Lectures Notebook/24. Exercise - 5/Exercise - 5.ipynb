# %% [markdown]
# ## Create the Following Graphs using Pandas of Matplotlib
#
# - whichever is applicable
# - create with 90% similarity, not 100% exactly
# - same email (renatomaaliw3@yahoo.com) - indicate in the filename your name, better indicate name in the notebook

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Data 1

np.random.seed(10)

time_series = pd.DataFrame(np.random.randn(700), index = pd.date_range('2020-01-01', periods = 700), columns = ['values'])
time_series
# Out:
#               values
# 2020-01-01  1.331587
# 2020-01-02  0.715279
# 2020-01-03 -1.545400
# 2020-01-04 -0.008384
# 2020-01-05  0.621336
# ...              ...
# 2021-11-26 -0.074023
# 2021-11-27  2.204886
# 2021-11-28 -0.452089
# 2021-11-29 -0.209436
# 2021-11-30 -0.294684
#
# [700 rows x 1 columns]

# %%
# Data 2 (Iris Data Set)

iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Data 3 (Quezon Covid ECQ), dataset is available at our data set folder in github

quezon_covid = pd.read_csv('T:/03. GitHub/public_files/Data Sets/quezon_covid.csv') # this can change depending on your file location
quezon_covid['Date'] = pd.to_datetime(quezon_covid['Date'])
quezon_covid.set_index('Date', inplace = True)
quezon_covid
# Out:
#             Cumulative_Confirmed_Positive  Cumulative_Recovery  \
# Date
# 2020-03-12                              0                    0
# 2020-03-13                              0                    0
# 2020-03-14                              0                    0
# 2020-03-15                              1                    0
# 2020-03-16                              1                    0
# ...                                   ...                  ...
# 2020-07-26                            286                  196
# 2020-07-27                            288                  196
# 2020-07-28                            300                  199
# 2020-07-29                            316                  200
# 2020-07-30                            343                  202
#
#             Cumulative_Deaths  Daily_Confirmed_Cases  Daily_Recovery  \
# Date
# 2020-03-12                  0                      0               0
# ...

# %% [markdown]
# ### Line Plot 1

# %% [markdown]
# ### Line Plot 2

# %% [markdown]
# ### Line Plot 3

# %%
# Out:
# Text(0.5, 1.0, 'Quezon Cumulative Confirmed Positive Cases')

# %% [markdown]
# ### Line Plot 4

# %% [markdown]
# ### Bar Plot

# %%
# Iris Data index 25 sample, remove species column
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Stacked Plot

# %%
# iris
# Out:
# Text(0, 0.5, 'Measurements')

# %% [markdown]
# ### Histogram

# %%
# iris data histogram with bins of 40

# %% [markdown]
# ### Box Plot

# %% [markdown]
# ### Scatter Plot

# %%
# Iris data Scatter PLots

# %% [markdown]
# ### Pie Plot

# %%
# Samples 30, 31, 32
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000013E39D88>,
# ...
#       dtype=object)

# %% [markdown]
# ### Subplots

# %%
# Out:
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# ### Nested Plots

# %%
# use advanced matplotlib method using fig and ax
