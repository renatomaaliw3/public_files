# %% [markdown]
# # Plotting With Pandas Exercise
# This set of exercises will require you to use Pandas' plotting functionality alongside some matplotlib methods.
#
# * **All charts use the `billboard_charts.csv` dataset.**
# * **Import that dataset and parse the `date` column as a date.**
# * **Use the matplotlib theme `ggplot`**

# %%
# Imports

import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
billboard = pd.read_csv("https://raw.githubusercontent.com/renatomaaliw3/public_files/master/Data%20Sets/billboard_charts.csv", parse_dates=["date"])
billboard.head(3)
# Out:
#         date  rank           song                         artist  last-week  \
# 0 2021-06-11     1     Easy On Me                          Adele        1.0
# 1 2021-06-11     2           Stay  The Kid LAROI & Justin Bieber        2.0
# 2 2021-06-11     3  Industry Baby        Lil Nas X & Jack Harlow        3.0
#
#    peak-rank  weeks-on-board
# 0          1               3
# 1          1              16
# 2          1              14

# %% [markdown]
# ## 1. Bar Plot
#
# Create the bar plot seen.  It visualizes the top 10 artists who have spent the most weeks at number 1 in the dataset.
#
# * Notice the customized title
# * The figure is 8x6
# * Add in the x-axis label (use plt.xlabel, for y-axis use plt.ylabel)

# %%
# 1. Your Missing Codes Here

plt.ylabel("Artists")

# %%
# Out:
# Text(0, 0.5, 'Artists')

# %% [markdown]
# ## 2. Pie Chart
#
# Please create the pie chart seen in the image below.  It visualizes the various artists who charted with the song "Please Mr. Postman".
#
# * Add in the custom title "Please Mr. Postman Versions"
# * Explode by 0.1 (Gentle Persuasion), e.g. explode = [0,0,0.1]

# %%
# 2. Your Missing Codes Here

# %% [markdown]
# ## 3. Line Graph
# Create the line plot seen in the image below. It visualizes the performance of the song "Blinding Lights" versus its rank
#
# * The figure is 9x5
# * You need to set_index("date") to achieve the graph

# %%
# 3. Your Missing Codes Here

# %% [markdown]
# ## 4. Line Graph - 2
#
# Create the line plot seen in the image below.  It shows the chart performance (rank) of the following songs:
#
# * All I Want For Christmas Is You by Mariah Carey
# * Rockin' Around The Christmas Tree by Brenda Lee
# * Jingle Bell Rock by Bobby Helms
#
# **The date range spans from 2016-12-25 to 2021-01-01**

# %%
# 2016-12-25 to 2021-01-01

plt.figure(figsize=(10,7))
df = billboard[billboard["date"].between("2016-12-25", "2021-01-01")].set_index("date")


# 4. Your Missing Codes Here


plt.legend()
plt.ylabel("Chart Rank")
plt.title("Christmas Songs On The Hot 100")

# %%
# Out:
# Text(0.5, 1.0, 'Christmas Songs On The Hot 100')

# %% [markdown]
# ## 5. Box Plot
#
# * Create the a box plot based on 'weeks-on-board' greater than 20
# **The date range spans from 2016-12-25 to 2021-01-01** (use previous df)

# %%
# 5. Your Missing Codes Here

# %%
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ## 6. Stacked Bar Plot
#
# Create the a stacked bar plot based on 'weeks-on-board' greater than 55
# Graph Size is 10,5
# * **The date range spans from 2016-12-25 to 2021-01-01** (use previous df)

# %%
# 6. Your Missing Codes Here

# %% [markdown]
# ## 7. Histogram
# * Create the a histogram where peak-rank is greater than or equal to 10
# * Graph Size is (10,5), bin size = 25
# * **The date range spans from 2016-12-25 to 2021-01-01** (use previous df)

# %%
# 7. Your Missing Codes Here
