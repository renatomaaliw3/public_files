# %% [markdown]
# # SQL in Python

# %%
# Imports

import sqlite3
import pandas as pd

# %%
# Load data

data = pd.read_csv('https://raw.githubusercontent.com/renatomaaliw3/public_files/master/Data%20Sets/summer.csv')
data
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
# Connect to an in memory SQLite Database

conn = sqlite3.connect(':memory')

# %%
# Write the DataFrame to the Database

data.to_sql('Summer', conn, index = False, if_exists = 'replace')
# Out:
# 31165

# %%
# Execute a SQL Query

query = "SELECT * FROM Summer"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
# Notes

# 00. SELECT (Extract)
# 0. AS (Alias)
# 1. WHERE (Certain conditions), NOT, AND, OR Comparison Operator (<,>,=, etc.)
# 2. ORDER BY, By DEFAULT ASC
# 3. LIKE (Wildcard -> For String), %, _
# 4. GROUP BY, HAVING (Aggregation Function)
# 5. (AVG, COUNT, SUM, MAX, MIN), (DISTINCT) -> unique
# 6. IN
# 7. BETWEEN
# 8. UNION, etc.

# Powerpoint presentation available on our github: "00. Presentations & Text Books/01. Electives 1 to 3"

# %%
# All Columns

query = "SELECT * FROM Summer"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
# Specific Columns

query = "SELECT City, Athlete FROM Summer"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#          City                    Athlete
# 0      Athens              HAJOS, Alfred
# 1      Athens           HERSCHMANN, Otto
# 2      Athens          DRIVAS, Dimitrios
# 3      Athens         MALOKINIS, Ioannis
# 4      Athens         CHASAPIS, Spiridon
# ...       ...                        ...
# 31160  London         JANIKOWSKI, Damian
# 31161  London  REZAEI, Ghasem Gholamreza
# 31162  London             TOTROV, Rustam
# 31163  London          ALEKSANYAN, Artur
# 31164  London             LIDBERG, Jimmy
#
# [31165 rows x 2 columns]

# %%
# AS (Alias)

query = "SELECT City, Athlete AS [Pangalan] FROM Summer"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#          City                   Pangalan
# 0      Athens              HAJOS, Alfred
# 1      Athens           HERSCHMANN, Otto
# 2      Athens          DRIVAS, Dimitrios
# 3      Athens         MALOKINIS, Ioannis
# 4      Athens         CHASAPIS, Spiridon
# ...       ...                        ...
# 31160  London         JANIKOWSKI, Damian
# 31161  London  REZAEI, Ghasem Gholamreza
# 31162  London             TOTROV, Rustam
# 31163  London          ALEKSANYAN, Artur
# 31164  London             LIDBERG, Jimmy
#
# [31165 rows x 2 columns]

# %%
# WHERE (AND)

query = "SELECT * FROM Summer "
query += "WHERE Event = '100M Freestyle' AND Medal = 'Gold'"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#     Year                   City     Sport Discipline  \
# 0   1896                 Athens  Aquatics   Swimming
# 1   1904               St Louis  Aquatics   Swimming
# 2   1908                 London  Aquatics   Swimming
# 3   1912              Stockholm  Aquatics   Swimming
# 4   1912              Stockholm  Aquatics   Swimming
# 5   1920                Antwerp  Aquatics   Swimming
# 6   1920                Antwerp  Aquatics   Swimming
# 7   1924                  Paris  Aquatics   Swimming
# 8   1924                  Paris  Aquatics   Swimming
# 9   1928              Amsterdam  Aquatics   Swimming
# 10  1928              Amsterdam  Aquatics   Swimming
# 11  1932            Los Angeles  Aquatics   Swimming
# 12  1932            Los Angeles  Aquatics   Swimming
# 13  1936                 Berlin  Aquatics   Swimming
# 14  1936                 Berlin  Aquatics   Swimming
# 15  1948                 London  Aquatics   Swimming
# 16  1948                 London  Aquatics   Swimming
# 17  1952               Helsinki  Aquatics   Swimming
# 18  1952               Helsinki  Aquatics   Swimming
# 19  1956  Melbourne / Stockholm  Aquatics   Swimming
# 20  1956  Melbourne / Stockholm  Aquatics   Swimming
# 21  1960                   Rome  Aquatics   Swimming
# 22  1960                   Rome  Aquatics   Swimming
# 23  1964                  Tokyo  Aquatics   Swimming
# 24  1964                  Tokyo  Aquatics   Swimming
# 25  1968                 Mexico  Aquatics   Swimming
# 26  1968                 Mexico  Aquatics   Swimming
# 27  1972                 Munich  Aquatics   Swimming
# 28  1972                 Munich  Aquatics   Swimming
# 29  1976               Montreal  Aquatics   Swimming
# 30  1976               Montreal  Aquatics   Swimming
# 31  1980                 Moscow  Aquatics   Swimming
# 32  1980                 Moscow  Aquatics   Swimming
# 33  1984            Los Angeles  Aquatics   Swimming
# 34  1984            Los Angeles  Aquatics   Swimming
# 35  1984            Los Angeles  Aquatics   Swimming
# 36  1988                  Seoul  Aquatics   Swimming
# 37  1988                  Seoul  Aquatics   Swimming
# 38  1992              Barcelona  Aquatics   Swimming
# 39  1992              Barcelona  Aquatics   Swimming
# 40  1996                Atlanta  Aquatics   Swimming
# 41  1996                Atlanta  Aquatics   Swimming
# 42  2000                 Sydney  Aquatics   Swimming
# 43  2000                 Sydney  Aquatics   Swimming
# 44  2004                 Athens  Aquatics   Swimming
# 45  2004                 Athens  Aquatics   Swimming
# 46  2008                Beijing  Aquatics   Swimming
# 47  2008                Beijing  Aquatics   Swimming
# 48  2012                 London  Aquatics   Swimming
# 49  2012                 London  Aquatics   Swimming
#
#                        Athlete Country Gender           Event Medal
# 0                HAJOS, Alfred     HUN    Men  100M Freestyle  Gold
# 1               HALMAY, Zoltan     HUN    Men  100M Freestyle  Gold
# 2             DANIELS, Charles     USA    Men  100M Freestyle  Gold
# 3        KAHANAMOKU, Duke Paoa     USA    Men  100M Freestyle  Gold
# 4                DURACK, Fanny     ANZ  Women  100M Freestyle  Gold
# 5        KAHANAMOKU, Duke Paoa     USA    Men  100M Freestyle  Gold
# 6           BLEIBTREY, Ethelda     USA  Women  100M Freestyle  Gold
# 7          WEISSMULLER, Johnny     USA    Men  100M Freestyle  Gold
# 8                LACKIE, Ethel     USA  Women  100M Freestyle  Gold
# 9          WEISSMULLER, Johnny     USA    Men  100M Freestyle  Gold
# 10      OSIPOWICH, Albina Lucy     USA  Women  100M Freestyle  Gold
# 11           MIOYAZAKI, Yasuji     JPN    Men  100M Freestyle  Gold
# 12             MADISON, Helene     USA  Women  100M Freestyle  Gold
# 13                CSIK, Ferenc     HUN    Men  100M Freestyle  Gold
# 14       MASTENBROEK, Hendrika     NED  Women  100M Freestyle  Gold
# 15         RIS, Walter Stephen     USA    Men  100M Freestyle  Gold
# 16       ANDERSEN, Greta Marie     DEN  Women  100M Freestyle  Gold
# 17       SCHOLES, Clark Currie     USA    Men  100M Freestyle  Gold
# 18              SZÖKE, Katalin     HUN  Women  100M Freestyle  Gold
# 19       HENRICKS, Jon Malcolm     AUS    Men  100M Freestyle  Gold
# 20                FRASER, Dawn     AUS  Women  100M Freestyle  Gold
# 21                DEVITT, John     AUS    Men  100M Freestyle  Gold
# 22                FRASER, Dawn     AUS  Women  100M Freestyle  Gold
# 23  SCHOLLANDER, Donald Arthur     USA    Men  100M Freestyle  Gold
# 24                FRASER, Dawn     AUS  Women  100M Freestyle  Gold
# 25     WENDEN, Michael Vincent     AUS    Men  100M Freestyle  Gold
# 26           HENNE, Jane Margo     USA  Women  100M Freestyle  Gold
# 27                 SPITZ, Mark     USA    Men  100M Freestyle  Gold
# 28     NEILSON, Alexandra Lynn     USA  Women  100M Freestyle  Gold
# 29      MONTGOMERY, James Paul     USA    Men  100M Freestyle  Gold
# 30             ENDER, Kornelia     GDR  Women  100M Freestyle  Gold
# 31                WOITHE, Jörg     GDR    Men  100M Freestyle  Gold
# 32             KRAUSE, Barbara     GDR  Women  100M Freestyle  Gold
# 33          GAINES, Ambrose Iv     USA    Men  100M Freestyle  Gold
# 34        HOGSHEAD, Nancy Lynn     USA  Women  100M Freestyle  Gold
# 35        STEINSEIFER, Carolyn     USA  Women  100M Freestyle  Gold
# 36             BIONDI, Matthew     USA    Men  100M Freestyle  Gold
# 37               OTTO, Kristin     GDR  Women  100M Freestyle  Gold
# 38            POPOV, Alexander     EUN    Men  100M Freestyle  Gold
# 39                ZHUANG, Yong     CHN  Women  100M Freestyle  Gold
# 40            POPOV, Alexander     RUS    Men  100M Freestyle  Gold
# 41                  LE, Jingyi     CHN  Women  100M Freestyle  Gold
# 42  VAN DEN HOOGENBAND, Pieter     NED    Men  100M Freestyle  Gold
# 43             DE BRUIJN, Inge     NED  Women  100M Freestyle  Gold
# 44  VAN DEN HOOGENBAND, Pieter     NED    Men  100M Freestyle  Gold
# 45                HENRY, Jodie     AUS  Women  100M Freestyle  Gold
# 46              BERNARD, Alain     FRA    Men  100M Freestyle  Gold
# 47             STEFFEN, Britta     GER  Women  100M Freestyle  Gold
# 48              ADRIAN, Nathan     USA    Men  100M Freestyle  Gold
# 49        KROMOWIDJOJO, Ranomi     NED  Women  100M Freestyle  Gold

# %%
# WHERE (OR)

query = "SELECT * FROM Summer "
query += "WHERE Event = '100M Freestyle' OR Event = '200M Freestyle'"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#      Year    City     Sport Discipline               Athlete Country Gender  \
# 0    1896  Athens  Aquatics   Swimming         HAJOS, Alfred     HUN    Men
# 1    1896  Athens  Aquatics   Swimming      HERSCHMANN, Otto     AUT    Men
# 2    1900   Paris  Aquatics   Swimming          RUBERL, Karl     AUT    Men
# 3    1900   Paris  Aquatics   Swimming  LANE, Frederick C.V.     AUS    Men
# 4    1900   Paris  Aquatics   Swimming        HALMAY, Zoltan     HUN    Men
# ..    ...     ...       ...        ...                   ...     ...    ...
# 221  2012  London  Aquatics   Swimming         PARK, Taehwan     KOR    Men
# 222  2012  London  Aquatics   Swimming             SUN, Yang     CHN    Men
# 223  2012  London  Aquatics   Swimming      SCHMITT, Allison     USA  Women
# 224  2012  London  Aquatics   Swimming       MUFFAT, Camille     FRA  Women
# 225  2012  London  Aquatics   Swimming       BARRATT, Bronte     AUS  Women
#
#               Event   Medal
# 0    100M Freestyle    Gold
# 1    100M Freestyle  Silver
# 2    200M Freestyle  Bronze
# 3    200M Freestyle    Gold
# 4    200M Freestyle  Silver
# ..              ...     ...
# 221  200M Freestyle  Silver
# 222  200M Freestyle  Silver
# 223  200M Freestyle    Gold
# 224  200M Freestyle  Silver
# 225  200M Freestyle  Bronze
#
# [226 rows x 9 columns]

# %%
# WHERE (NOT)

query = "SELECT * FROM Summer "
query += "WHERE NOT City = 'Athens'"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#        Year    City      Sport           Discipline  \
# 0      1900   Paris   Aquatics             Swimming
# 1      1900   Paris   Aquatics             Swimming
# 2      1900   Paris   Aquatics             Swimming
# 3      1900   Paris   Aquatics             Swimming
# 4      1900   Paris   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 29011  2012  London  Wrestling  Wrestling Freestyle
# 29012  2012  London  Wrestling  Wrestling Freestyle
# 29013  2012  London  Wrestling  Wrestling Freestyle
# 29014  2012  London  Wrestling  Wrestling Freestyle
# 29015  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender            Event   Medal
# 0                 HALMAY, Zoltan     HUN    Men  1500M Freestyle  Bronze
# 1            JARVIS, John Arthur     GBR    Men  1500M Freestyle    Gold
# 2                    WAHLE, Otto     AUT    Men  1500M Freestyle  Silver
# 3                DROST, Johannes     NED    Men  200M Backstroke  Bronze
# 4              HOPPENBERG, Ernst     GER    Men  200M Backstroke    Gold
# ...                          ...     ...    ...              ...     ...
# 29011         JANIKOWSKI, Damian     POL    Men         Wg 84 KG  Bronze
# 29012  REZAEI, Ghasem Gholamreza     IRI    Men         Wg 96 KG    Gold
# 29013             TOTROV, Rustam     RUS    Men         Wg 96 KG  Silver
# 29014          ALEKSANYAN, Artur     ARM    Men         Wg 96 KG  Bronze
# 29015             LIDBERG, Jimmy     SWE    Men         Wg 96 KG  Bronze
#
# [29016 rows x 9 columns]

# %%
# LIKE (Wildcard %)

query = "SELECT * FROM Summer "
query += " WHERE Athlete LIKE '%ak%' AND Gender = 'Men'"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#      Year    City      Sport           Discipline  \
# 0    1896  Athens  Athletics            Athletics
# 1    1896  Athens  Athletics            Athletics
# 2    1896  Athens  Athletics            Athletics
# 3    1896  Athens    Fencing              Fencing
# 4    1896  Athens    Fencing              Fencing
# ..    ...     ...        ...                  ...
# 690  2012  London   Shooting             Shooting
# 691  2012  London  Wrestling  Wrestling Freestyle
# 692  2012  London  Wrestling  Wrestling Freestyle
# 693  2012  London  Wrestling  Wrestling Freestyle
# 694  2012  London  Wrestling  Wrestling Freestyle
#
#                                Athlete Country Gender             Event  \
# 0                        BLAKE, Arthur     USA    Men             1500M
# 1                 VASILAKOS, Kharilaos     GRE    Men          Marathon
# 2                    PERSAKIS, Ioannis     GRE    Men       Triple Jump
# 3    PIERRAKOS-MAVROMICHALIS, Perikles     GRE    Men   Foil Individual
# 4                KARAKALOS, Telemachos     GRE    Men  Sabre Individual
# ..                                 ...     ...    ...               ...
# 690                      DAHLBY, Hakan     SWE    Men   Double Trap 150
# 691                     MAKHOV, Bilyal     RUS    Men          Wf 120KG
# 692                TANATAROV, Akzhurek     KAZ    Men          Wf 66 KG
# 693                 JULFALAKYAN, Arsen     ARM    Men          Wg 74 KG
# 694               KAZAKEVIC, Aleksandr     LTU    Men          Wg 74 KG
#
#       Medal
# 0    Silver
# 1    Silver
# 2    Bronze
# 3    Bronze
# 4    Silver
# ..      ...
# 690  Silver
# 691  Bronze
# 692  Bronze
# 693  Silver
# 694  Bronze
#
# [695 rows x 9 columns]

# %%
# LIKE (Wildcard _) - Exact

query = "SELECT * FROM Summer WHERE Athlete LIKE '_____' AND Gender = 'Men'"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#     Year      City       Sport Discipline Athlete Country Gender  \
# 0   1900     Paris    Aquatics   Swimming   CADET     FRA    Men
# 1   1900     Paris     Croquet    Croquet   JOHIN     FRA    Men
# 2   1900     Paris     Croquet    Croquet   JOHIN     FRA    Men
# 3   1904  St Louis    Lacrosse   Lacrosse   WOODS     USA    Men
# 4   1904  St Louis    Lacrosse   Lacrosse   YOUNG     USA    Men
# 5   1920   Antwerp  Equestrian   Vaulting   FIELD     FRA    Men
# 6   1920   Antwerp  Equestrian   Vaulting   FIELD     FRA    Men
# 7   1980    Moscow  Equestrian   Dressage   IGROK     URS    Men
# 8   1980    Moscow  Equestrian   Dressage   IGROK     URS    Men
# 9   1980    Moscow  Equestrian   Dressage   ALEKO     BUL    Men
# 10  1980    Moscow  Equestrian    Jumping   TOPKI     URS    Men
# 11  1996   Atlanta    Football   Football   SAVIO     BRA    Men
# 12  2008   Beijing    Football   Football   BRENO     BRA    Men
# 13  2008   Beijing    Football   Football   DIEGO     BRA    Men
# 14  2008   Beijing    Football   Football   LUCAS     BRA    Men
# 15  2008   Beijing    Football   Football   RENAN     BRA    Men
# 16  2012    London    Football   Football   GANSO     BRA    Men
# 17  2012    London    Football   Football   OSCAR     BRA    Men
#
#                        Event   Medal
# 0         200M Team Swimming  Silver
# 1                     Double    Gold
# 2          Individual 1 Ball  Silver
# 3                   Lacrosse  Silver
# 4                   Lacrosse  Silver
# 5   Figure Riding Individual  Silver
# 6         Figure Riding Team  Silver
# 7                 Individual  Silver
# 8                       Team    Gold
# 9                       Team  Silver
# 10                      Team    Gold
# 11                  Football  Bronze
# 12                  Football  Bronze
# 13                  Football  Bronze
# 14                  Football  Bronze
# 15                  Football  Bronze
# 16                  Football  Silver
# 17                  Football  Silver

# %%
# LIKE (Wildcard _)

query = "SELECT * FROM Summer WHERE Athlete LIKE 'A____R' AND Gender = 'Men'"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#    Year     City     Sport Discipline Athlete Country Gender     Event   Medal
# 0  1996  Atlanta  Football   Football  ALDAIR     BRA    Men  Football  Bronze

# %%
# LIKE (Wildcard _ , %)

query = "SELECT * FROM Summer WHERE Athlete LIKE 'A_R%' AND Gender = 'Men'"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#     Year      City       Sport           Discipline                   Athlete  \
# 0   1896    Athens    Aquatics             Swimming          ANDREOU, Joannis
# 1   1896    Athens  Gymnastics          Artistic G.  ANDRIAKOPOULOS, Nicolaos
# 2   1896    Athens  Gymnastics          Artistic G.  ANDRIAKOPOULOS, Nicolaos
# 3   1900     Paris     Cricket              Cricket             ATTRILL, W.T.
# 4   1904  St Louis     Cycling        Cycling Track        ANDREWS, Arthur F.
# ..   ...       ...         ...                  ...                       ...
# 95  2008   Beijing    Football             Football              AMBROSE, Efe
# 96  2008   Beijing  Volleyball           Volleyball             AMARAL, Dante
# 97  2012    London     Fencing              Fencing       ASPROMONTE, Valerio
# 98  2012    London  Volleyball           Volleyball             AMARAL, Dante
# 99  2012    London   Wrestling  Wrestling Freestyle       ANDRIITSEV, Valerii
#
#    Country Gender                Event   Medal
# 0      GRE    Men      1200M Freestyle  Silver
# 1      GRE    Men        Rope Climbing    Gold
# 2      GRE    Men  Team, Parallel Bars  Silver
# 3      FRA    Men              Cricket  Silver
# 4      USA    Men  25 Miles (40.232KM)  Silver
# ..     ...    ...                  ...     ...
# 95     NGR    Men             Football  Silver
# 96     BRA    Men           Volleyball  Silver
# 97     ITA    Men            Foil Team    Gold
# 98     BRA    Men           Volleyball  Silver
# 99     UKR    Men             Wf 96 KG  Silver
#
# [100 rows x 9 columns]

# %%
# LIKE (Wildcard _ , %)

query = "SELECT * FROM Summer WHERE Athlete LIKE '%A__R' AND Gender = 'Men'"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#      Year         City      Sport           Discipline  \
# 0    1904     St Louis     Rowing               Rowing
# 1    1904     St Louis     Tennis               Tennis
# 2    1912    Stockholm  Athletics            Athletics
# 3    1912    Stockholm    Sailing              Sailing
# 4    1932  Los Angeles    Fencing              Fencing
# ..    ...          ...        ...                  ...
# 239  2012       London     Rowing               Rowing
# 240  2012       London  Wrestling  Wrestling Freestyle
# 241  2012       London  Wrestling  Wrestling Freestyle
# 242  2012       London  Wrestling  Wrestling Freestyle
# 243  2012       London  Wrestling  Wrestling Freestyle
#
#                           Athlete Country Gender                     Event  \
# 0            SCHELL, Frank Reaner     USA    Men  Eight With Coxswain (8+)
# 1            WEST, Allen Tarwater     USA    Men                   Doubles
# 2            NELSON, Frank Thayer     USA    Men                Pole Vault
# 3             RODIONOV, Aleksandr     RU1    Men                       10M
# 4                GEREVICH, Aladar     HUN    Men                Sabre Team
# ..                            ...     ...    ...                       ...
# 239                 MARTIN, Damir     CRO    Men          Quadruple Sculls
# 240                  HATOS, Gabor     HUN    Men                  Wf 74 KG
# 241         LASHGARI, Ehsan Naser     IRI    Men                  Wf 84 KG
# 242          KAZAKEVIC, Aleksandr     LTU    Men                  Wg 74 KG
# 243  EBRAHIM, Karam Mohamed Gaber     EGY    Men                  Wg 84 KG
#
#       Medal
# 0      Gold
# 1    Bronze
# 2    Silver
# 3    Bronze
# 4      Gold
# ..      ...
# 239  Silver
# 240  Bronze
# 241  Bronze
# 242  Bronze
# 243  Silver
#
# [244 rows x 9 columns]

# %%
# ORDER BY (ASC, DEC)

query = "SELECT * FROM Summer "
query += "WHERE Event = '100M Freestyle' "
query += " AND Medal = 'Gold' AND Country = 'USA' AND Gender = 'Men' "
query += "ORDER BY Athlete DESC"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#     Year         City     Sport Discipline                     Athlete  \
# 0   1924        Paris  Aquatics   Swimming         WEISSMULLER, Johnny
# 1   1928    Amsterdam  Aquatics   Swimming         WEISSMULLER, Johnny
# 2   1972       Munich  Aquatics   Swimming                 SPITZ, Mark
# 3   1964        Tokyo  Aquatics   Swimming  SCHOLLANDER, Donald Arthur
# 4   1952     Helsinki  Aquatics   Swimming       SCHOLES, Clark Currie
# 5   1948       London  Aquatics   Swimming         RIS, Walter Stephen
# 6   1976     Montreal  Aquatics   Swimming      MONTGOMERY, James Paul
# 7   1912    Stockholm  Aquatics   Swimming       KAHANAMOKU, Duke Paoa
# 8   1920      Antwerp  Aquatics   Swimming       KAHANAMOKU, Duke Paoa
# 9   1984  Los Angeles  Aquatics   Swimming          GAINES, Ambrose Iv
# 10  1908       London  Aquatics   Swimming            DANIELS, Charles
# 11  1988        Seoul  Aquatics   Swimming             BIONDI, Matthew
# 12  2012       London  Aquatics   Swimming              ADRIAN, Nathan
#
#    Country Gender           Event Medal
# 0      USA    Men  100M Freestyle  Gold
# 1      USA    Men  100M Freestyle  Gold
# 2      USA    Men  100M Freestyle  Gold
# 3      USA    Men  100M Freestyle  Gold
# 4      USA    Men  100M Freestyle  Gold
# 5      USA    Men  100M Freestyle  Gold
# 6      USA    Men  100M Freestyle  Gold
# 7      USA    Men  100M Freestyle  Gold
# 8      USA    Men  100M Freestyle  Gold
# 9      USA    Men  100M Freestyle  Gold
# 10     USA    Men  100M Freestyle  Gold
# 11     USA    Men  100M Freestyle  Gold
# 12     USA    Men  100M Freestyle  Gold

# %%
# LIMIT

query = "SELECT * FROM Summer WHERE Medal = 'Gold' AND Country = 'USA'"
query += " AND Gender = 'Women' ORDER BY Athlete DESC LIMIT 5"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#    Year         City       Sport  Discipline               Athlete Country  \
# 0  2004       Athens     Fencing     Fencing       ZAGUNIS, Mariel     USA
# 1  2008      Beijing     Fencing     Fencing       ZAGUNIS, Mariel     USA
# 2  1904     St Louis     Archery     Archery       WOODRUFF, Laura     USA
# 3  1920      Antwerp    Aquatics    Swimming  WOODBRIDGE, Margaret     USA
# 4  1984  Los Angeles  Basketball  Basketball      WOODARD, Lynette     USA
#
#   Gender                   Event Medal
# 0  Women        Sabre Individual  Gold
# 1  Women        Sabre Individual  Gold
# 2  Women        Teams Fita Round  Gold
# 3  Women  4X100M Freestyle Relay  Gold
# 4  Women              Basketball  Gold

# %%
# LIMIT

query = "SELECT * FROM Summer WHERE Medal = 'Gold' AND Country = 'USA'"
query += " AND Gender = 'Women' ORDER BY Athlete DESC LIMIT 0, 3"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#    Year      City    Sport Discipline          Athlete Country Gender  \
# 0  2004    Athens  Fencing    Fencing  ZAGUNIS, Mariel     USA  Women
# 1  2008   Beijing  Fencing    Fencing  ZAGUNIS, Mariel     USA  Women
# 2  1904  St Louis  Archery    Archery  WOODRUFF, Laura     USA  Women
#
#               Event Medal
# 0  Sabre Individual  Gold
# 1  Sabre Individual  Gold
# 2  Teams Fita Round  Gold

# %%
# GROUP BY, Aggregation Function, COUNT, MAX, MIN, AVG, SUM)

query = "SELECT Country, COUNT(Medal) AS [Medal_Count] "
query += "FROM Summer WHERE COUNTRY = 'PHI' "
query += "GROUP BY Country ORDER BY Medal_Count DESC"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#   Country  Medal_Count
# 0     PHI            9

# %%
# GROUP BY, HAVING (Aggregation Function, COUNT, MAX, MIN, AVG, SUM)

query = "SELECT Country, Medal, COUNT(Medal) AS [Medal_Count] FROM Summer "
query += "GROUP BY Medal, Country "
query += "HAVING (Country = 'PHI') ORDER BY Medal_Count DESC"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#   Country   Medal  Medal_Count
# 0     PHI  Bronze            7
# 1     PHI  Silver            2

# %%
# DISTINCT

query = "SELECT DISTINCT(Country) FROM Summer"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#     Country
# 0       HUN
# 1       AUT
# 2       GRE
# 3       USA
# 4       GER
# ..      ...
# 143     BOT
# 144     MNE
# 145     CYP
# 146     SGP
# 147     GAB
#
# [148 rows x 1 columns]

# %%
# DISTINCT

query = "SELECT COUNT(DISTINCT(Country)) AS 'Participating Country' FROM Summer"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#    Participating Country
# 0                    147

# %%
# IN (Shorthand OR), Can be used in WHERE or HAVING

query = "SELECT Country, COUNT(Medal) FROM Summer GROUP BY Country "
query += "HAVING Country IN ('USA', 'AUS', 'CAN')"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#   Country  COUNT(Medal)
# 0     AUS          1189
# 1     CAN           649
# 2     USA          4585

# %%
# BETWEEN (Shorthand for Ranges), Can be used in WHERE or HAVING

query = "SELECT Year, Athlete, Event FROM Summer "
query += " WHERE (Year BETWEEN 1896 AND 1912) AND (Event = '100M Freestyle')"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#     Year                Athlete           Event
# 0   1896          HAJOS, Alfred  100M Freestyle
# 1   1896       HERSCHMANN, Otto  100M Freestyle
# 2   1904        LEARY, J. Scott  100M Freestyle
# 3   1904         HALMAY, Zoltan  100M Freestyle
# 4   1904       DANIELS, Charles  100M Freestyle
# 5   1908     JULIN, Harald S.A.  100M Freestyle
# 6   1908       DANIELS, Charles  100M Freestyle
# 7   1908         HALMAY, Zoltan  100M Freestyle
# 8   1912       HUSZAGH, Kenneth  100M Freestyle
# 9   1912  KAHANAMOKU, Duke Paoa  100M Freestyle
# 10  1912           HEALY, Cecil  100M Freestyle
# 11  1912       FLETCHER, Jennie  100M Freestyle
# 12  1912          DURACK, Fanny  100M Freestyle
# 13  1912      WYLIE, Wilhelmina  100M Freestyle

# %%
# UNION (Combine)

query = "SELECT Year, Athlete, Event FROM Summer "
query += "WHERE Year BETWEEN 1896 AND 1912 AND (Event = '100M Freestyle')"
query += "UNION "
query += "SELECT Year, Athlete, Event FROM Summer "
query += "WHERE Year BETWEEN 1896 AND 1912 AND (Event = '200M Freestyle')"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#     Year                Athlete           Event
# 0   1896          HAJOS, Alfred  100M Freestyle
# 1   1896       HERSCHMANN, Otto  100M Freestyle
# 2   1900         HALMAY, Zoltan  200M Freestyle
# 3   1900   LANE, Frederick C.V.  200M Freestyle
# 4   1900           RUBERL, Karl  200M Freestyle
# 5   1904       DANIELS, Charles  100M Freestyle
# 6   1904       DANIELS, Charles  200M Freestyle
# 7   1904        GAILEY, Francis  200M Freestyle
# 8   1904         HALMAY, Zoltan  100M Freestyle
# 9   1904        LEARY, J. Scott  100M Freestyle
# 10  1904           RAUSCH, Emil  200M Freestyle
# 11  1908       DANIELS, Charles  100M Freestyle
# 12  1908         HALMAY, Zoltan  100M Freestyle
# 13  1908     JULIN, Harald S.A.  100M Freestyle
# 14  1912          DURACK, Fanny  100M Freestyle
# 15  1912       FLETCHER, Jennie  100M Freestyle
# 16  1912           HEALY, Cecil  100M Freestyle
# 17  1912       HUSZAGH, Kenneth  100M Freestyle
# 18  1912  KAHANAMOKU, Duke Paoa  100M Freestyle
# 19  1912      WYLIE, Wilhelmina  100M Freestyle
