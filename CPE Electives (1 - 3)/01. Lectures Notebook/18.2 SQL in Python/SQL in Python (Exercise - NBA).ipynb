# %% [markdown]
# # SQL in Python (Exercises)

# %%
# Imports

import sqlite3
import pandas as pd

# %%
# Load data

data = pd.read_csv('https://raw.githubusercontent.com/renatomaaliw3/public_files/refs/heads/master/Data%20Sets/nba%20cleaned.csv')
data.head(5)
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7     215    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5     225   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5     195     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10     256  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10     240     Maryland
#
#      Salary
# 0   4556983
# 1  18700000
# 2   4094244
# 3  20616000
# 4   2581522

# %%
# Modifications

data['Height_'] = data['Height'].str.replace('-', '.').astype(float)

# %%
# Connect to an in memory SQLite Database

conn = sqlite3.connect(':memory:')

# %%
# Write the DataFrame to the Database

data.to_sql('NBA', conn, index = False, if_exists = 'replace')
# Out:
# 583

# %%
# Execute a SQL Query

query = "SELECT * FROM NBA"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7     215
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5     225
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5     195
# 3         Clint Capela       Atlanta Hawks        C   6-10     256
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10     240
# ..                 ...                 ...      ...    ...     ...
# 578       Jordan Poole  Washington Wizards        G    6-4     194
# 579       Ryan Rollins  Washington Wizards        G    6-3     180
# 580      Landry Shamet  Washington Wizards        G    6-4     190
# 581   Tristan Vukcevic  Washington Wizards        F   6-10     220
# 582       Delon Wright  Washington Wizards        G    6-5     185
#
#            College    Salary  Height_
# 0        Villanova   4556983      6.7
# 1       Fenerbahce  18700000      6.5
# 2         Michigan   4094244      6.5
# 3      Elan Chalon  20616000      6.1
# 4         Maryland   2581522      6.1
# ..             ...       ...      ...
# 578       Michigan  27955357      6.4
# 579         Toledo   1719864      6.3
# 580  Wichita State  10250000      6.4
# 581    Real Madrid         0      6.1
# 582           Utah   8195122      6.5
#
# [583 rows x 8 columns]

# %%
# 01. What is the total payroll for the Golden State Warriors

query = "SELECT Team, SUM(Salary) AS [Total Salary] FROM NBA "
query += "WHERE Team = 'Golden State Warriors' "

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#                     Team  Total Salary
# 0  Golden State Warriors     209671207

# %%
# 02. Can you identify what team is the tallest in terms of average player height?

query = "SELECT Team, AVG(Height_) AS 'AVG_Height' FROM NBA "
query += "GROUP BY Team ORDER BY AVG_Height DESC "

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#                       Team  AVG_Height
# 0         Sacramento Kings    6.677778
# 1   Portland Trail Blazers    6.658824
# 2           Boston Celtics    6.650000
# 3          Toronto Raptors    6.635000
# 4        Charlotte Hornets    6.606000
# 5     Los Angeles Clippers    6.600000
# 6       Los Angeles Lakers    6.590000
# 7          New York Knicks    6.580952
# 8           Indiana Pacers    6.571905
# 9    Oklahoma City Thunder    6.571905
# 10         Milwaukee Bucks    6.564091
# 11  Minnesota Timberwolves    6.557895
# 12            Phoenix Suns    6.553158
# 13         Detroit Pistons    6.553158
# 14       San Antonio Spurs    6.545500
# 15               Utah Jazz    6.521000
# 16              Miami Heat    6.519048
# 17       Memphis Grizzlies    6.518636
# 18           Brooklyn Nets    6.518235
# 19   Golden State Warriors    6.517647
# 20          Denver Nuggets    6.516000
# 21           Chicago Bulls    6.505789
# 22      Philadelphia 76ers    6.496190
# 23        Dallas Mavericks    6.491364
# 24      Washington Wizards    6.486190
# 25     Cleveland Cavaliers    6.485263
# 26         Houston Rockets    6.471500
# 27    New Orleans Pelicans    6.470625
# 28           Atlanta Hawks    6.465294
# 29           Orlando Magic    6.434444

# %%
# 03. Who are the tallest and shortest player in the NBA under contract? (Hint: We will use UNION to display in one query)

query = "SELECT * FROM NBA WHERE Height_ = (SELECT MAX(Height_) FROM NBA WHERE Salary != 0) "
query += "UNION "
query += "SELECT * FROM NBA WHERE Height_ = (SELECT MIN(Height_) FROM NBA WHERE Salary != 0) "

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#                 Name               Team Position Height  Weight  \
# 0    Markquis Nowell    Toronto Raptors        G    5-8     160
# 1  Victor Wembanyama  San Antonio Spurs      F-C    7-4     210
#
#             College    Salary  Height_
# 0      Kansas State    559782      5.8
# 1  Metropolitans 92  12160632      7.4

# %%
# 04. Which team has the most players who play two positions?

query = "SELECT Team, COUNT(Position) AS [2WayPlayers] FROM NBA "
query += " WHERE Position LIKE '%-%'"
query += "GROUP BY Team  "
query += "ORDER BY [2WayPlayers] DESC"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#                       Team  2WayPlayers
# 0          New York Knicks            8
# 1           Indiana Pacers            8
# 2           Boston Celtics            8
# 3        San Antonio Spurs            7
# 4             Phoenix Suns            7
# 5   Minnesota Timberwolves            5
# 6          Houston Rockets            5
# 7         Dallas Mavericks            5
# 8                Utah Jazz            4
# 9          Toronto Raptors            4
# 10        Sacramento Kings            4
# 11  Portland Trail Blazers            4
# 12      Philadelphia 76ers            4
# 13           Orlando Magic            4
# 14              Miami Heat            4
# 15      Los Angeles Lakers            4
# 16    Los Angeles Clippers            4
# 17     Cleveland Cavaliers            4
# 18   Oklahoma City Thunder            3
# 19    New Orleans Pelicans            3
# 20   Golden State Warriors            3
# 21         Detroit Pistons            3
# 22           Brooklyn Nets            3
# 23           Atlanta Hawks            3
# 24      Washington Wizards            2
# 25       Memphis Grizzlies            2
# 26          Denver Nuggets            2
# 27       Charlotte Hornets            2
# 28         Milwaukee Bucks            1
# 29           Chicago Bulls            1

# %%
# 05. Find the average salary of players grouped by each unique height,
#     and filter only the heights with more than 3 players.
#     Then, display the results sorted by average salary in descending order.

query = "SELECT Height_, COUNT(*) AS [Player_Count], AVG(Salary) AS [Average_Salary] FROM NBA "
query += "GROUP BY Height "
query += "HAVING Player_Count > 3 "
query += "ORDER BY Average_Salary DESC "

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#     Height_  Player_Count  Average_Salary
# 0      7.10            33    1.233314e+07
# 1      6.20            29    1.053380e+07
# 2      6.10            31    1.004137e+07
# 3      6.40            53    8.234721e+06
# 4      6.80            60    8.113891e+06
# 5      6.10            36    8.023816e+06
# 6      6.50            74    7.426138e+06
# 7      6.70            72    6.909398e+06
# 8      6.60            69    6.877540e+06
# 9      6.11            30    6.306839e+06
# 10     6.90            58    5.668035e+06
# 11     6.30            29    5.373410e+06
# 12     7.20             4    2.484938e+06

# %%
#06. Find the highest-paid/lowest salary within each team,
#    along with the player’s name and salary.

query = "SELECT Name, Team, Position, MAX(Salary) AS [Highest_Salary] FROM NBA "
query += "GROUP BY Team "
query += "ORDER BY Highest_Salary DESC "

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#                        Name                    Team Position  Highest_Salary
# 0             Stephen Curry   Golden State Warriors        G        51915615
# 1              Kevin Durant            Phoenix Suns        F        47649433
# 2               Joel Embiid      Philadelphia 76ers      C-F        47607350
# 3              LeBron James      Los Angeles Lakers        F        47607350
# 4              Nikola Jokic          Denver Nuggets        C        47607350
# 5            Damian Lillard  Portland Trail Blazers        G        45640084
# 6     Giannis Antetokounmpo         Milwaukee Bucks        F        45640084
# 7               Paul George    Los Angeles Clippers        F        45640084
# 8              Jimmy Butler              Miami Heat        F        45183960
# 9               Rudy Gobert  Minnesota Timberwolves        C        41000000
# 10            Fred VanVleet         Houston Rockets        G        40806300
# 11              Luka Doncic        Dallas Mavericks      F-G        40064220
# 12              Zach LaVine           Chicago Bulls        G        40064220
# 13               Trae Young           Atlanta Hawks        G        40064220
# 14            Pascal Siakam         Toronto Raptors        F        37893408
# 15              Ben Simmons           Brooklyn Nets      G-F        37893408
# 16       Kristaps Porzingis          Boston Celtics      F-C        36016200
# 17              CJ McCollum    New Orleans Pelicans        G        35802469
# 18                Ja Morant       Memphis Grizzlies        G        34005250
# 19           Darius Garland     Cleveland Cavaliers        G        34005250
# 20  Shai Gilgeous-Alexander   Oklahoma City Thunder        G        33386850
# 21             De'Aaron Fox        Sacramento Kings        G        32600060
# 22           Gordon Hayward       Charlotte Hornets        F        31500000
# 23            Julius Randle         New York Knicks      F-C        28226880
# 24             Jordan Poole      Washington Wizards        G        27955357
# 25             John Collins               Utah Jazz      F-C        25340000
# 26              Bruce Brown          Indiana Pacers      G-F        22000000
# 27           Keldon Johnson       San Antonio Spurs      F-G        20000000
# 28         Bojan Bogdanovic         Detroit Pistons        F        20000000
# 29           Jonathan Isaac           Orlando Magic        F        17400000

# %%
#07. Calculate the salary disparity within each team by finding the difference between
#    the highest-paid and lowest-paid player on each team.

query = "SELECT Team, MAX(Salary) - MIN(Salary) AS [Salary_Disparity] FROM NBA "
query += "GROUP BY Team "
query += "ORDER BY Salary_Disparity DESC "

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#                       Team  Salary_Disparity
# 0    Golden State Warriors          51915615
# 1             Phoenix Suns          47649433
# 2       Philadelphia 76ers          47607350
# 3       Los Angeles Lakers          47607350
# 4           Denver Nuggets          47607350
# 5   Portland Trail Blazers          45640084
# 6          Milwaukee Bucks          45640084
# 7     Los Angeles Clippers          45640084
# 8               Miami Heat          45183960
# 9   Minnesota Timberwolves          41000000
# 10         Houston Rockets          40806300
# 11        Dallas Mavericks          40064220
# 12           Chicago Bulls          40064220
# 13           Atlanta Hawks          39555329
# 14         Toronto Raptors          37893408
# 15           Brooklyn Nets          37893408
# 16          Boston Celtics          36016200
# 17    New Orleans Pelicans          35802469
# 18       Memphis Grizzlies          34005250
# 19     Cleveland Cavaliers          34005250
# 20   Oklahoma City Thunder          32827068
# 21        Sacramento Kings          32600060
# 22       Charlotte Hornets          31500000
# 23         New York Knicks          28226880
# 24      Washington Wizards          27955357
# 25               Utah Jazz          24780218
# 26          Indiana Pacers          22000000
# 27       San Antonio Spurs          20000000
# 28         Detroit Pistons          20000000
# 29           Orlando Magic          17400000

# %%
#08. Find the total number of players league-wide who can
#    play multiple positions of (F-G) or (G-F) and display this count.

query = "SELECT COUNT(Position) AS [Multi_Position] FROM NBA "
query += "WHERE Position IN ('F-G', 'G-F') "

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#    Multi_Position
# 0              61

# %%
#09. Which team has the most players that belongs to the same college?

query = "SELECT Team, College, COUNT(*) AS [Same_College] FROM NBA "
query += "GROUP BY Team, College "
query += "ORDER BY Same_College DESC LIMIT 5"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#                Team          College  Same_College
# 0     Orlando Magic         Michigan             4
# 1  Sacramento Kings         Kentucky             4
# 2     Brooklyn Nets  Louisiana State             3
# 3  Dallas Mavericks             Duke             3
# 4    Indiana Pacers          Arizona             3

# %%
#10. Find the highest salary for each unique positions in the league, display the name and team of the player

query = "SELECT Name, Team, Position, MAX(Salary) AS [Highest_Salary_Per_Position] FROM NBA "
query += "GROUP BY Position "
query += "ORDER BY Highest_Salary_Per_Position DESC"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#             Name                   Team Position  Highest_Salary_Per_Position
# 0  Stephen Curry  Golden State Warriors        G                     51915615
# 1   Kevin Durant           Phoenix Suns        F                     47649433
# 2    Joel Embiid     Philadelphia 76ers      C-F                     47607350
# 3   Nikola Jokic         Denver Nuggets        C                     47607350
# 4  Anthony Davis     Los Angeles Lakers      F-C                     40600080
# 5    Luka Doncic       Dallas Mavericks      F-G                     40064220
# 6    Ben Simmons          Brooklyn Nets      G-F                     37893408

# %%
#11. Find the average salary for each unique positions in the league, display the name and team of the player

query = "SELECT Position, AVG(Salary) AS [Average_Salary_Per_Position] FROM NBA "
query += "GROUP BY Position "
query += "ORDER BY Average_Salary_Per_Position DESC"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#   Position  Average_Salary_Per_Position
# 0      F-G                 1.197028e+07
# 1      C-F                 9.649498e+06
# 2      F-C                 8.655115e+06
# 3        G                 7.955230e+06
# 4        C                 7.925774e+06
# 5      G-F                 7.881014e+06
# 6        F                 6.515844e+06
