# %% [markdown]
# # SQL in Python

# %%
# Imports

import sqlite3
import pandas as pd

# %%
# Load data

data = pd.read_csv('https://raw.githubusercontent.com/renatomaaliw3/public_files/master/Data%20Sets/summer.csv')
data.head(5)
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
# Connect to an in memory SQLite Database

conn = sqlite3.connect(':memory')

# %%
# Write the DataFrame to the Database

data.to_sql('Summer', conn, iindex = False, if_exists = 'replace')
# Out:
# 31165

# %%
# Execute a SQL Query

query = "SELECT * FROM Summer"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
# Notes

# 00. SELECT (Extract)
# 0. AS (Alias)
# 1. WHERE (Certain conditions), NOT, AND, OR Comparison Operator (<,>,=, etc.)
# 2. ORDER BY, By DEFAULT ASC
# 3. LIKE (Wildcard -> For String), %, _
# 4. GROUP BY, HAVING (Aggregation Function)
# 5. (AVG, COUNT, SUM, MAX, MIN), (DISTINCT) -> unique
# 6. IN
# 7. BETWEEN
# 8. UNION, etc.

# %%
# Specific Columns

query = "SELECT City, Athlete FROM Summer"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#          City                    Athlete
# 0      Athens              HAJOS, Alfred
# 1      Athens           HERSCHMANN, Otto
# 2      Athens          DRIVAS, Dimitrios
# 3      Athens         MALOKINIS, Ioannis
# 4      Athens         CHASAPIS, Spiridon
# ...       ...                        ...
# 31160  London         JANIKOWSKI, Damian
# 31161  London  REZAEI, Ghasem Gholamreza
# 31162  London             TOTROV, Rustam
# 31163  London          ALEKSANYAN, Artur
# 31164  London             LIDBERG, Jimmy
#
# [31165 rows x 2 columns]

# %%
# Alias

query = "SELECT City, Athlete AS 'Full Name' FROM Summer"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#          City                  Full Name
# 0      Athens              HAJOS, Alfred
# 1      Athens           HERSCHMANN, Otto
# 2      Athens          DRIVAS, Dimitrios
# 3      Athens         MALOKINIS, Ioannis
# 4      Athens         CHASAPIS, Spiridon
# ...       ...                        ...
# 31160  London         JANIKOWSKI, Damian
# 31161  London  REZAEI, Ghasem Gholamreza
# 31162  London             TOTROV, Rustam
# 31163  London          ALEKSANYAN, Artur
# 31164  London             LIDBERG, Jimmy
#
# [31165 rows x 2 columns]

# %%
# WHERE

query = "SELECT * FROM Summer WHERE Event = '100M Freestyle' AND Medal = 'Gold' AND Country = 'USA' AND Gender = 'Men'"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#     Year         City     Sport Discipline                     Athlete  \
# 0   1908       London  Aquatics   Swimming            DANIELS, Charles
# 1   1912    Stockholm  Aquatics   Swimming       KAHANAMOKU, Duke Paoa
# 2   1920      Antwerp  Aquatics   Swimming       KAHANAMOKU, Duke Paoa
# 3   1924        Paris  Aquatics   Swimming         WEISSMULLER, Johnny
# 4   1928    Amsterdam  Aquatics   Swimming         WEISSMULLER, Johnny
# 5   1948       London  Aquatics   Swimming         RIS, Walter Stephen
# 6   1952     Helsinki  Aquatics   Swimming       SCHOLES, Clark Currie
# 7   1964        Tokyo  Aquatics   Swimming  SCHOLLANDER, Donald Arthur
# 8   1972       Munich  Aquatics   Swimming                 SPITZ, Mark
# 9   1976     Montreal  Aquatics   Swimming      MONTGOMERY, James Paul
# 10  1984  Los Angeles  Aquatics   Swimming          GAINES, Ambrose Iv
# 11  1988        Seoul  Aquatics   Swimming             BIONDI, Matthew
# 12  2012       London  Aquatics   Swimming              ADRIAN, Nathan
#
#    Country Gender           Event Medal
# 0      USA    Men  100M Freestyle  Gold
# 1      USA    Men  100M Freestyle  Gold
# 2      USA    Men  100M Freestyle  Gold
# 3      USA    Men  100M Freestyle  Gold
# 4      USA    Men  100M Freestyle  Gold
# 5      USA    Men  100M Freestyle  Gold
# 6      USA    Men  100M Freestyle  Gold
# 7      USA    Men  100M Freestyle  Gold
# 8      USA    Men  100M Freestyle  Gold
# 9      USA    Men  100M Freestyle  Gold
# 10     USA    Men  100M Freestyle  Gold
# 11     USA    Men  100M Freestyle  Gold
# 12     USA    Men  100M Freestyle  Gold

# %%
# ORDER BY

query = "SELECT * FROM Summer WHERE Event = '100M Freestyle'"
query += " AND Medal = 'Gold' AND Country = 'USA' AND Gender = 'Men' ORDER BY Athlete DESC"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#     Year         City     Sport Discipline                     Athlete  \
# 0   1924        Paris  Aquatics   Swimming         WEISSMULLER, Johnny
# 1   1928    Amsterdam  Aquatics   Swimming         WEISSMULLER, Johnny
# 2   1972       Munich  Aquatics   Swimming                 SPITZ, Mark
# 3   1964        Tokyo  Aquatics   Swimming  SCHOLLANDER, Donald Arthur
# 4   1952     Helsinki  Aquatics   Swimming       SCHOLES, Clark Currie
# 5   1948       London  Aquatics   Swimming         RIS, Walter Stephen
# 6   1976     Montreal  Aquatics   Swimming      MONTGOMERY, James Paul
# 7   1912    Stockholm  Aquatics   Swimming       KAHANAMOKU, Duke Paoa
# 8   1920      Antwerp  Aquatics   Swimming       KAHANAMOKU, Duke Paoa
# 9   1984  Los Angeles  Aquatics   Swimming          GAINES, Ambrose Iv
# 10  1908       London  Aquatics   Swimming            DANIELS, Charles
# 11  1988        Seoul  Aquatics   Swimming             BIONDI, Matthew
# 12  2012       London  Aquatics   Swimming              ADRIAN, Nathan
#
#    Country Gender           Event Medal
# 0      USA    Men  100M Freestyle  Gold
# 1      USA    Men  100M Freestyle  Gold
# 2      USA    Men  100M Freestyle  Gold
# 3      USA    Men  100M Freestyle  Gold
# 4      USA    Men  100M Freestyle  Gold
# 5      USA    Men  100M Freestyle  Gold
# 6      USA    Men  100M Freestyle  Gold
# 7      USA    Men  100M Freestyle  Gold
# 8      USA    Men  100M Freestyle  Gold
# 9      USA    Men  100M Freestyle  Gold
# 10     USA    Men  100M Freestyle  Gold
# 11     USA    Men  100M Freestyle  Gold
# 12     USA    Men  100M Freestyle  Gold

# %%
# LIMIT

query = "SELECT * FROM Summer WHERE Event = '100M Freestyle' AND Medal = 'Gold' AND Country = 'USA'"
query += " AND Gender = 'Men' ORDER BY Athlete DESC LIMIT 3"

result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#    Year       City     Sport Discipline              Athlete Country Gender  \
# 0  1924      Paris  Aquatics   Swimming  WEISSMULLER, Johnny     USA    Men
# 1  1928  Amsterdam  Aquatics   Swimming  WEISSMULLER, Johnny     USA    Men
# 2  1972     Munich  Aquatics   Swimming          SPITZ, Mark     USA    Men
#
#             Event Medal
# 0  100M Freestyle  Gold
# 1  100M Freestyle  Gold
# 2  100M Freestyle  Gold

# %%
# LIKE (Wildcard %)

query = "SELECT * FROM Summer WHERE Athlete LIKE '%kyo%' AND Gender = 'Men'"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#    Year         City       Sport           Discipline           Athlete  \
# 0  1968       Mexico      Boxing               Boxing  CHANG, Kyou-Chul
# 1  1984  Los Angeles  Gymnastics          Artistic G.   YAMAWAKI, Kyoji
# 2  1996      Atlanta     Archery              Archery      OH, Kyo-Moon
# 3  1996      Atlanta     Archery              Archery      OH, Kyo-Moon
# 4  2000       Sydney     Archery              Archery      OH, Kyo-Moon
# 5  2000       Sydney   Taekwondo            Taekwondo    KIM, Kyong-Hun
# 6  2012       London    Football             Football     YUN, Sukyoung
# 7  2012       London   Wrestling  Wrestling Freestyle    YANG, Kyong Il
#
#   Country Gender                                  Event   Medal
# 0     KOR    Men               51 - 54KG (Bantamweight)  Bronze
# 1     JPN    Men                       Team Competition  Bronze
# 2     KOR    Men  Individual (Fita Olympic Round - 70M)  Bronze
# 3     KOR    Men        Team (Fita Olympic Round - 70M)  Silver
# 4     KOR    Men        Team (Fita Olympic Round - 70M)    Gold
# 5     KOR    Men                                + 80 KG    Gold
# 6     KOR    Men                               Football  Bronze
# 7     PRK    Men                               Wf 55 KG  Bronze

# %%
# LIKE (Wildcard _) - Exact

query = "SELECT * FROM Summer WHERE Athlete LIKE '_______' AND Gender = 'Men'"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#     Year       City          Sport       Discipline  Athlete Country Gender  \
# 0   1900      Paris       Aquatics         Swimming  TARTARA     FRA    Men
# 1   1900      Paris       Aquatics       Water polo  DEVENOT     FRA    Men
# 2   1900      Paris       Aquatics       Water polo  LERICHE     FRA    Men
# 3   1900      Paris       Football         Football  FRAYSSE     FRA    Men
# 4   1900      Paris       Football         Football  LAMBERT     FRA    Men
# 5   1900      Paris       Football         Football  MACAIRE     FRA    Men
# 6   1900      Paris       Football         Football  PELTIER     FRA    Men
# 7   1900      Paris         Rowing           Rowing  CHARLOT     FRA    Men
# 8   1900      Paris       Shooting         Shooting  TRINITE     FRA    Men
# 9   1904   St Louis       Football         Football  DIERKES     USA    Men
# 10  1904   St Louis       Football         Football  DIERKES     USA    Men
# 11  1980     Moscow     Equestrian         Dressage  DECEBAL     ROU    Men
# 12  1980     Moscow     Equestrian         Dressage  DERBIST     ROU    Men
# 13  1980     Moscow     Equestrian         Dressage  SCHIBOR     BUL    Men
# 14  1980     Moscow     Equestrian         Eventing  PINTSET     URS    Men
# 15  1980     Moscow     Equestrian         Eventing  PINTSET     URS    Men
# 16  1980     Moscow     Equestrian         Eventing  TSKHETI     URS    Men
# 17  1980     Moscow     Equestrian          Jumping  GEPATIT     URS    Men
# 18  1992  Barcelona   Table Tennis     Table Tennis  LU, Lin     CHN    Men
# 19  1992  Barcelona      Wrestling  Wrestling Free.  KIM, Il     PRK    Men
# 20  1996    Atlanta       Football         Football  DANRLEI     BRA    Men
# 21  1996    Atlanta       Football         Football  JUNINHO     BRA    Men
# 22  1996    Atlanta       Football         Football  NARCISO     BRA    Men
# 23  1996    Atlanta       Football         Football  RIVALDO     BRA    Men
# 24  1996    Atlanta   Table Tennis     Table Tennis  LU, Lin     CHN    Men
# 25  1996    Atlanta      Wrestling  Wrestling Free.  KIM, Il     PRK    Men
# 26  2000     Sydney       Aquatics           Diving  HU, Jia     CHN    Men
# 27  2000     Sydney       Aquatics           Diving  HU, Jia     CHN    Men
# 28  2004     Athens       Aquatics           Diving  HU, Jia     CHN    Men
# 29  2004     Athens       Shooting         Shooting  LI, Jie     CHN    Men
# 30  2004     Athens   Table Tennis     Table Tennis  MA, Lin     CHN    Men
# 31  2008    Beijing       Football         Football  ILSINHO     BRA    Men
# 32  2008    Beijing       Football         Football  MARCELO     BRA    Men
# 33  2008    Beijing       Football         Football  RAFINHA     BRA    Men
# 34  2008    Beijing       Football         Football  RAMIRES     BRA    Men
# 35  2008    Beijing   Table Tennis     Table Tennis  MA, Lin     CHN    Men
# 36  2008    Beijing   Table Tennis     Table Tennis  MA, Lin     CHN    Men
# 37  2012     London       Aquatics           Diving  QIU, Bo     CHN    Men
# 38  2012     London       Football         Football  GABRIEL     BRA    Men
# 39  2012     London       Football         Football  MARCELO     BRA    Men
# 40  2012     London  Weightlifting    Weightlifting  Pending    None    Men
#
#                                   Event   Medal
# 0                    200M Team Swimming  Bronze
# 1                            Water Polo  Bronze
# 2                            Water Polo  Bronze
# 3                              Football  Silver
# 4                              Football  Silver
# 5                              Football  Silver
# 6                              Football  Silver
# 7   Four-Oared Shell With Coxswain (4-)    Gold
# 8                 50M Army Pistol, Team  Silver
# 9                              Football  Bronze
# 10                             Football    Gold
# 11                                 Team  Bronze
# 12                                 Team  Bronze
# 13                                 Team  Silver
# 14                           Individual  Bronze
# 15                                 Team    Gold
# 16                                 Team    Gold
# 17                                 Team    Gold
# 18                              Doubles    Gold
# 19             - 48KG (Light-Flyweight)    Gold
# 20                             Football  Bronze
# 21                             Football  Bronze
# 22                             Football  Bronze
# 23                             Football  Bronze
# 24                              Doubles  Silver
# 25             - 48KG (Light-Flyweight)    Gold
# 26                         10M Platform  Silver
# 27     Synchronized Diving 10M Platform  Silver
# 28                         10M Platform    Gold
# 29             10M Air Rifle (60 Shots)  Silver
# 30                              Doubles    Gold
# 31                             Football  Bronze
# 32                             Football  Bronze
# 33                             Football  Bronze
# 34                             Football  Bronze
# 35                              Singles    Gold
# 36                                 Team    Gold
# 37                         10M Platform  Silver
# 38                             Football  Silver
# 39                             Football  Silver
# 40                                 94KG  Silver

# %%
# LIKE (Wildcard _)

query = "SELECT * FROM Summer WHERE Athlete LIKE 'A____R%' AND Gender = 'Men'"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#     Year                   City          Sport       Discipline  \
# 0   1904               St Louis      Athletics        Athletics
# 1   1904               St Louis         Rowing           Rowing
# 2   1908                 London        Fencing          Fencing
# 3   1908                 London        Fencing          Fencing
# 4   1912              Stockholm        Sailing          Sailing
# 5   1920                Antwerp        Archery          Archery
# 6   1920                Antwerp        Archery          Archery
# 7   1920                Antwerp        Archery          Archery
# 8   1920                Antwerp     Equestrian         Eventing
# 9   1920                Antwerp        Fencing          Fencing
# 10  1920                Antwerp        Fencing          Fencing
# 11  1920                Antwerp       Shooting         Shooting
# 12  1920                Antwerp         Tennis           Tennis
# 13  1924                  Paris  Weightlifting    Weightlifting
# 14  1924                  Paris      Wrestling  Wrestling Gre-R
# 15  1932            Los Angeles         Boxing           Boxing
# 16  1932            Los Angeles        Sailing          Sailing
# 17  1948                 London      Athletics        Athletics
# 18  1948                 London         Boxing           Boxing
# 19  1948                 London         Hockey           Hockey
# 20  1948                 London      Wrestling  Wrestling Free.
# 21  1956  Melbourne / Stockholm         Hockey           Hockey
# 22  1964                  Tokyo      Athletics        Athletics
# 23  1964                  Tokyo      Athletics        Athletics
# 24  1968                 Mexico        Sailing          Sailing
# 25  1972                 Munich         Hockey           Hockey
# 26  1972                 Munich         Hockey           Hockey
# 27  1976               Montreal     Basketball       Basketball
# 28  1976               Montreal         Hockey           Hockey
# 29  1984            Los Angeles       Aquatics         Swimming
# 30  1988                  Seoul       Aquatics         Swimming
# 31  1988                  Seoul       Aquatics         Swimming
# 32  1988                  Seoul        Cycling     Cycling Road
# 33  1996                Atlanta       Football         Football
# 34  2000                 Sydney      Badminton        Badminton
# 35  2000                 Sydney        Cycling     Cycling Road
# 36  2000                 Sydney       Shooting         Shooting
# 37  2004                 Athens       Shooting         Shooting
# 38  2008                Beijing      Athletics        Athletics
# 39  2008                Beijing       Football         Football
# 40  2008                Beijing       Handball         Handball
# 41  2012                 London          Canoe     Canoe Slalom
#
#                              Athlete Country Gender  \
# 0                  ASHBURNER, Lesley     USA    Men
# 1              ARMSTRONG, Charles E.     USA    Men
# 2                    ALIBERT, Gaston     FRA    Men
# 3                    ALIBERT, Gaston     FRA    Men
# 4                     AHNGER, Arthur     FIN    Men
# 5                  ALLAERT, Alphonse     BEL    Men
# 6                  ALLAERT, Alphonse     BEL    Men
# 7                  ALLAERT, Alphonse     BEL    Men
# 8                     ASINARI, Carlo     ITA    Men
# 9                  ABELARDO, Olivier     ITA    Men
# 10                 ABELARDO, Olivier     ITA    Men
# 11                 AMOUDRUZ, Gustave     SUI    Men
# 12                  ALBARRAN, Pierre     FRA    Men
# 13                     AIGNER, Franz     AUT    Men
# 14                   AHLFORS, Anselm     FIN    Men
# 15            AHLBERG, Bruno Valfrid     FIN    Men
# 16       ASTHER, Gunnar Anton Edvard     SWE    Men
# 17                      ARCHER, John     GBR    Men
# 18                      ARTHUR, John     RSA    Men
# 19                   AHKTAR, Hussain     IND    Men
# 20                 ARMSTRONG, Joseph     AUS    Men
# 21                   AHKTAR, Hussain     PAK    Men
# 22           ASHWORTH, Gerald Howard     USA    Men
# 23                         AUN, Rein     URS    Men
# 24           AISHER, Robin Allingham     GBR    Men
# 25                    AKHTAR, Rasool     PAK    Men
# 26                  AKHTAR, Ul Islam     PAK    Men
# 27  ARMSTRONG, Michael Taylor (Tate)     USA    Men
# 28                    AKHTAR, Rasool     PAK    Men
# 29                   ASTBURY, Andrew     GBR    Men
# 30            ARMSTRONG, Duncan John     AUS    Men
# 31            ARMSTRONG, Duncan John     AUS    Men
# 32                       AMPLER, Uwe     GDR    Men
# 33                            ALDAIR     BRA    Men
# 34                     ARCHER, Simon     GBR    Men
# 35               ARMSTRONG, Lance E.     USA    Men
# 36                ALIFIRENKO, Sergei     RUS    Men
# 37                ALIFIRENKO, Sergei     RUS    Men
# 38                 ASAHARA, Nobuharu     JPN    Men
# 39                 AJILORE, Ebenezer     NGR    Men
# 40                ASGEIRSSON, Sturla     ISL    Men
# 41                    AIGNER, Hannes     GER    Men
#
#                                             Event   Medal
# 0                                    110M Hurdles  Bronze
# 1                        Eight With Coxswain (8+)    Gold
# 2                                 Épée Individual    Gold
# 3                                       Épée Team    Gold
# 4                                              8M  Bronze
# 5                    Moving Bird Target 28M Teams  Silver
# 6                    Moving Bird Target 33M Teams    Gold
# 7                    Moving Bird Target 50M Teams    Gold
# 8                                            Team  Silver
# 9                                       Épée Team    Gold
# 10                                      Foil Team    Gold
# 11                          30M Army Pistol, Team  Bronze
# 12                                        Doubles  Bronze
# 13  + 82.5KG, One-Two Hand 5 Events (Heavyweight)  Silver
# 14                          - 58KG (Bantamweight)  Silver
# 15                 61.24 - 66.68KG (Welterweight)  Bronze
# 16                Two-Person Keelboat Open (Star)  Bronze
# 17                                   4X100M Relay  Silver
# 18                           + 80KG (Heavyweight)  Bronze
# 19                                         Hockey    Gold
# 20                           + 87KG (Heavyweight)  Bronze
# 21                                         Hockey  Silver
# 22                                   4X100M Relay    Gold
# 23                                      Decathlon  Silver
# 24                                           5.5M  Bronze
# 25                                         Hockey  Silver
# 26                                         Hockey  Silver
# 27                                     Basketball    Gold
# 28                                         Hockey  Bronze
# 29                         4X200M Freestyle Relay  Bronze
# 30                                 200M Freestyle    Gold
# 31                                 400M Freestyle  Silver
# 32                                Team Time Trial    Gold
# 33                                       Football  Bronze
# 34                                        Doubles  Bronze
# 35                          Individual Time Trial  Bronze
# 36               25M Rapid Fire Pistol (60 Shots)    Gold
# 37               25M Rapid Fire Pistol (60 Shots)  Bronze
# 38                                   4X100M Relay  Bronze
# 39                                       Football  Silver
# 40                                       Handball  Silver
# 41                                   K-1 (Single)  Bronze

# %%
# GROUP BY, Aggregation Function, COUNT, MAX, MIN, AVG, SUM)

query = "SELECT Country, COUNT(Medal) AS 'Medal Count' FROM Summer GROUP BY Country ORDER BY Count(Medal)"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#     Country  Medal Count
# 0       AHO            1
# 1       BAR            1
# 2       BDI            1
# 3       BER            1
# 4       BOT            1
# ..      ...          ...
# 143     GER         1305
# 144     FRA         1396
# 145     GBR         1720
# 146     URS         2049
# 147     USA         4585
#
# [148 rows x 2 columns]

# %%
# GROUP BY, HAVING (Aggregation Function, COUNT, MAX, MIN, AVG, SUM)

query = "SELECT Country, COUNT(Medal) AS 'Medal Count' FROM Summer"
query += " GROUP BY Country HAVING Country = 'USA' OR Country = 'PHI' ORDER BY Count(Medal) DESC"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#   Country  Medal Count
# 0     USA         4585
# 1     PHI            9

# %%
# DISTINCT

query = "SELECT DISTINCT(Country) FROM Summer"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#     Country
# 0       HUN
# 1       AUT
# 2       GRE
# 3       USA
# 4       GER
# ..      ...
# 143     BOT
# 144     MNE
# 145     CYP
# 146     SGP
# 147     GAB
#
# [148 rows x 1 columns]

# %%
# DISTINCT

query = "SELECT COUNT(DISTINCT(Country)) AS 'Participating Country' FROM Summer"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#    Participating Country
# 0                    147

# %%
# IN (Shorthand OR), Can be used in WHERE or HAVING

query = "SELECT Country, COUNT(Athlete) FROM Summer GROUP BY Country HAVING Country IN ('USA', 'AUS', 'CAN')"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#   Country  COUNT(Athlete)
# 0     AUS            1189
# 1     CAN             649
# 2     USA            4585

# %%
# BETWEEN (Shorthand for Ranges), Can be used in WHERE or HAVING

query = "SELECT Year, Athlete, Event FROM Summer WHERE Year BETWEEN 1896 AND 1912 AND (Event = '100M Freestyle')"
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#     Year                Athlete           Event
# 0   1896          HAJOS, Alfred  100M Freestyle
# 1   1896       HERSCHMANN, Otto  100M Freestyle
# 2   1904        LEARY, J. Scott  100M Freestyle
# 3   1904         HALMAY, Zoltan  100M Freestyle
# 4   1904       DANIELS, Charles  100M Freestyle
# 5   1908     JULIN, Harald S.A.  100M Freestyle
# 6   1908       DANIELS, Charles  100M Freestyle
# 7   1908         HALMAY, Zoltan  100M Freestyle
# 8   1912       HUSZAGH, Kenneth  100M Freestyle
# 9   1912  KAHANAMOKU, Duke Paoa  100M Freestyle
# 10  1912           HEALY, Cecil  100M Freestyle
# 11  1912       FLETCHER, Jennie  100M Freestyle
# 12  1912          DURACK, Fanny  100M Freestyle
# 13  1912      WYLIE, Wilhelmina  100M Freestyle
