# %% [markdown]
# ## GeoPandas

# %%
# Imports

import pandas as pd
import matplotlib.pyplot as plt

import geopandas as gpd

import warnings
warnings.filterwarnings('ignore')

# %%
# Read and Process GeoJSON data
# If you are familiar with with Pandas, the transition will be easy

gdf = gpd.read_file('https://raw.githubusercontent.com/renatomaaliw3/public_files/master/Data%20Sets/GeoData/gadm41_PHL_2.json')
gdf.to_csv('data.csv')

# head, tail, columns, crs, geometry

# %%
# Calculate centroids

gdf['centroid_x'] = gdf['geometry'].centroid.x
gdf['centroid_y'] = gdf['geometry'].centroid.y

gdf
# Out:
#             GID_2 GID_0      COUNTRY     GID_1            NAME_1 NL_NAME_1  \
# 0       PHL.1.1_1   PHL  Philippines   PHL.1_1              Abra        NA
# 1       PHL.1.2_1   PHL  Philippines   PHL.1_1              Abra        NA
# 2       PHL.1.3_1   PHL  Philippines   PHL.1_1              Abra        NA
# 3       PHL.1.4_1   PHL  Philippines   PHL.1_1              Abra        NA
# 4       PHL.1.5_1   PHL  Philippines   PHL.1_1              Abra        NA
# ...           ...   ...          ...       ...               ...       ...
# 1642  PHL.81.12_1   PHL  Philippines  PHL.81_1  ZamboangaSibugay        NA
# 1643  PHL.81.13_1   PHL  Philippines  PHL.81_1  ZamboangaSibugay        NA
# 1644  PHL.81.14_1   PHL  Philippines  PHL.81_1  ZamboangaSibugay        NA
# 1645  PHL.81.15_1   PHL  Philippines  PHL.81_1  ZamboangaSibugay        NA
# 1646  PHL.81.16_1   PHL  Philippines  PHL.81_1  ZamboangaSibugay        NA
#
#            NAME_2 VARNAME_2 NL_NAME_2           TYPE_2     ENGTYPE_2    CC_2  \
# 0         Bangued        NA        NA  Bayan|Munisipyo  Municipality  140101
# 1         Boliney        NA        NA  Bayan|Munisipyo  Municipality  140102
# 2           Bucay        NA        NA  Bayan|Munisipyo  Municipality  140103
# 3          Bucloc        NA        NA  Bayan|Munisipyo  Municipality  140104
# 4       Daguioman        NA        NA  Bayan|Munisipyo  Municipality  140105
# ...           ...       ...       ...              ...           ...     ...
# 1642  RosellerLim        NA        NA  Bayan|Munisipyo  Municipality   98312
# 1643         Siay        NA        NA  Bayan|Munisipyo  Municipality   98313
# 1644      Talusan        NA        NA  Bayan|Munisipyo  Municipality   98314
# 1645        Titay        NA        NA  Bayan|Munisipyo  Municipality   98315
# 1646     Tungawan        NA        NA  Bayan|Munisipyo  Municipality   98316
#
#         HASC_2                                           geometry  centroid_x  \
# 0     PH.AB.BN  MULTIPOLYGON (((120.6113 17.4956, 120.6055 17....  120.607094
# 1     PH.AB.BL  MULTIPOLYGON (((120.814 17.3421, 120.7686 17.3...  120.868131
# 2     PH.AB.BU  MULTIPOLYGON (((120.6777 17.4574, 120.6732 17....  120.722587
# 3     PH.AB.BC  MULTIPOLYGON (((120.7892 17.4452, 120.8846 17....  120.847782
# 4     PH.AB.DG  MULTIPOLYGON (((120.9075 17.4193, 120.8928 17....  120.951525
# ...        ...                                                ...         ...
# 1642  PH.ZS.RS  MULTIPOLYGON (((122.4742 7.63, 122.475 7.6267,...  122.424755
# 1643  PH.ZS.SA  MULTIPOLYGON (((122.8697 7.6548, 122.8676 7.65...  122.867228
# 1644  PH.ZS.TL  MULTIPOLYGON (((122.8945 7.3564, 122.9092 7.35...  122.855277
# 1645  PH.ZS.TT  MULTIPOLYGON (((122.4886 7.764, 122.4855 7.770...  122.578329
# 1646  PH.ZS.TN  MULTIPOLYGON (((122.2362 7.5427, 122.2535 7.57...  122.344600
#
#       centroid_y
# 0      17.600613
# 1      17.379642
# 2      17.522872
# 3      17.437573
# 4      17.451014
# ...          ...
# 1642    7.705188
# 1643    7.727850
# 1644    7.369784
# 1645    7.851549
# 1646    7.556426
#
# [1647 rows x 16 columns]

# %%
# Basic Plotting

# Create a plot with a custom figure size of 10 inches wide by 8 inches tall
fig, ax = plt.subplots(figsize=(25, 25))

x = gdf.query("NAME_1 == 'Quezon'")
x = x.drop(index = [1309])

x.plot(ax = ax, color = 'green', edgecolor = 'black')

# Add a title
ax.set_title("", pad = 40, fontweight = 'bold', fontsize = 18)

# Add grid
# ax.grid(alpha = 0.5)

# Remove x and y ticks
ax.set_xticks([])
ax.set_yticks([])

# Here is a simple approach to add text (x, y, 'text')
ax.text(0.50, 0.96, 'Quezon Province', transform = ax.transAxes, fontsize=36, fontweight='bold',
        ha='center', va='center', color='blue')


plt.show()

# %%
# Basic Plotting (Annotated)

# Create a plot with a custom figure size of 10 inches wide by 8 inches tall
fig, ax = plt.subplots(figsize=(25, 25))

x = gdf.query("NAME_1 == 'Quezon'")
x = x.drop(index = [1309])

x.plot(ax = ax, color = 'green', edgecolor = 'black')

# Add a title
ax.set_title("", pad = 40, fontweight = 'bold', fontsize = 18)

# Add grid
# ax.grid(alpha = 0.5)

# Remove x and y ticks
ax.set_xticks([])
ax.set_yticks([])

# Here is a simple approach to add text (x, y, 'text')
ax.text(0.50, 0.96, 'Quezon Province', transform = ax.transAxes, fontsize=36, fontweight='bold',
        ha='center', va='center', color='blue')

# Annotation with name of Municipalities
for idx, row in x.iterrows():

  ax.annotate(row['NAME_2'], xy = row['geometry'].centroid.coords[0], ha = 'center', va = 'center', fontsize = 10, color = 'black')

plt.show()
