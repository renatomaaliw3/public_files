# %% [markdown]
# # Pandas Operations

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Sample Dataset

# %%
d = {
    'Name'  : ['Wanda','Eric','John','Andy','Deborah','Charles','James'],
    'Sex': ['Female', 'Male', 'Male', 'Male','Female', 'Male','Male'],
    'City'  : ['Stamford', 'Stamford', 'New York', 'Philadelphia', 'Philadelphia','Stamford','New York'],
    'Frequency': ['Weekly', 'Daily','Weekly', 'Monthly', 'Daily', 'Weekly','Daily'],
    'Item'     : ['Burger', 'Chalupa', 'Sushi','Ice Cream', 'Chalupa', 'Sushi','Donut'],
    'Spend'    : [15,10,42,11,23,93,37]
}

# %%
df = pd.DataFrame(d)
df
# Out:
#       Name     Sex          City Frequency       Item  Spend
# 0    Wanda  Female      Stamford    Weekly     Burger     15
# 1     Eric    Male      Stamford     Daily    Chalupa     10
# 2     John    Male      New York    Weekly      Sushi     42
# 3     Andy    Male  Philadelphia   Monthly  Ice Cream     11
# 4  Deborah  Female  Philadelphia     Daily    Chalupa     23
# 5  Charles    Male      Stamford    Weekly      Sushi     93
# 6    James    Male      New York     Daily      Donut     37

# %%
# .head .tail() .sample()

df.sample()
# Out:
#    Name   Sex          City Frequency       Item  Spend
# 3  Andy  Male  Philadelphia   Monthly  Ice Cream     11

# %%
# .unique

df['Item'].unique() # show exact description of unique items
# Out:
# array(['Burger', 'Chalupa', 'Sushi', 'Ice Cream', 'Donut'], dtype=object)

# %%
len(df['Item'].unique()) # number of unique items
# df['Item'].nunique() # alternative
# Out:
# 5

# %%
df.nunique() # summary of each columns number of unique entities
# Out:
# Name         7
# Sex          2
# City         3
# Frequency    3
# Item         5
# Spend        7
# dtype: int64

# %%
# .value counts

df['Item'].value_counts() # count number of values
# Out:
# Item
# Chalupa      2
# Sushi        2
# Burger       1
# Ice Cream    1
# Donut        1
# Name: count, dtype: int64

# %%
# .apply()

def vat(x):

  return x * 0.02

# %%
df['Tax'] = df['Spend'].apply(vat)
df
# Out:
#       Name     Sex          City Frequency       Item  Spend   Tax
# 0    Wanda  Female      Stamford    Weekly     Burger     15  0.30
# 1     Eric    Male      Stamford     Daily    Chalupa     10  0.20
# 2     John    Male      New York    Weekly      Sushi     42  0.84
# 3     Andy    Male  Philadelphia   Monthly  Ice Cream     11  0.22
# 4  Deborah  Female  Philadelphia     Daily    Chalupa     23  0.46
# 5  Charles    Male      Stamford    Weekly      Sushi     93  1.86
# 6    James    Male      New York     Daily      Donut     37  0.74

# %%
# .sum, .mean() .std() .var() .count()

df['Spend'].count()
# Out:
# 7

# %%
# .columns, .index

df.columns
# Out:
# Index(['Name', 'Sex', 'City', 'Frequency', 'Item', 'Spend', 'Tax'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
# .pivot_table (PT)

df
# Out:
#       Name     Sex          City Frequency       Item  Spend   Tax
# 0    Wanda  Female      Stamford    Weekly     Burger     15  0.30
# 1     Eric    Male      Stamford     Daily    Chalupa     10  0.20
# 2     John    Male      New York    Weekly      Sushi     42  0.84
# 3     Andy    Male  Philadelphia   Monthly  Ice Cream     11  0.22
# 4  Deborah  Female  Philadelphia     Daily    Chalupa     23  0.46
# 5  Charles    Male      Stamford    Weekly      Sushi     93  1.86
# 6    James    Male      New York     Daily      Donut     37  0.74

# %%
# Sample PT - 1

df.pivot_table(values = 'Spend', columns = ['Item'], aggfunc = 'sum')
# Out:
# Item   Burger  Chalupa  Donut  Ice Cream  Sushi
# Spend      15       33     37         11    135

# %%
# Sample PT - 2

df.pivot_table(values = ['Spend', 'Tax'], columns = ['Item'], aggfunc = 'sum')
# Out:
# Item   Burger  Chalupa  Donut  Ice Cream  Sushi
# Spend    15.0    33.00  37.00      11.00  135.0
# Tax       0.3     0.66   0.74       0.22    2.7

# %%
# Sample PT - 3

df.pivot_table(values = ['Spend'], columns = ['City'], aggfunc = 'mean')
# Out:
# City   New York  Philadelphia   Stamford
# Spend      39.5          17.0  39.333333

# %%
# Sample PT -4

df.pivot_table(values = ['Spend', 'Tax'], columns = ['Sex'], aggfunc = 'sum')
# Out:
# Sex    Female    Male
# Spend   38.00  193.00
# Tax      0.76    3.86

# %% [markdown]
# # Data Input (Pandas)

# %%
# Reading of CSV files

df1 = pd.read_csv('https://raw.githubusercontent.com/renatomaaliw3/public_files/refs/heads/master/Data%20Sets/foods.csv') # .json, sql, .dat, etc.....
df1
# Out:
#     First Name  Gender          City Frequency       Item  Spend
# 0        Wanda  Female      Stamford    Weekly     Burger  15.66
# 1         Eric    Male      Stamford     Daily    Chalupa  10.56
# 2      Charles    Male      New York     Never      Sushi  42.14
# 3         Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4      Deborah  Female  Philadelphia     Daily    Chalupa  23.49
# ..         ...     ...           ...       ...        ...    ...
# 995      Donna  Female      New York   Monthly      Sushi  83.53
# 996     Albert    Male  Philadelphia     Daily      Sushi  72.88
# 997       Jean  Female      Stamford    Weekly      Donut   5.85
# 998    Jessica  Female      New York     Daily    Chalupa  43.19
# 999      Brian    Male      New York     Daily    Chalupa  28.36
#
# [1000 rows x 6 columns]

# %%
df1.head(5)
# Out:
#   First Name  Gender          City Frequency       Item  Spend
# 0      Wanda  Female      Stamford    Weekly     Burger  15.66
# 1       Eric    Male      Stamford     Daily    Chalupa  10.56
# 2    Charles    Male      New York     Never      Sushi  42.14
# 3       Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4    Deborah  Female  Philadelphia     Daily    Chalupa  23.49

# %%
df1.tail()
# Out:
#     First Name  Gender          City Frequency     Item  Spend
# 995      Donna  Female      New York   Monthly    Sushi  83.53
# 996     Albert    Male  Philadelphia     Daily    Sushi  72.88
# 997       Jean  Female      Stamford    Weekly    Donut   5.85
# 998    Jessica  Female      New York     Daily  Chalupa  43.19
# 999      Brian    Male      New York     Daily  Chalupa  28.36

# %%
df1.loc[:, 'Item':]
# Out:
#           Item  Spend
# 0       Burger  15.66
# 1      Chalupa  10.56
# 2        Sushi  42.14
# 3    Ice Cream  11.01
# 4      Chalupa  23.49
# ..         ...    ...
# 995      Sushi  83.53
# 996      Sushi  72.88
# 997      Donut   5.85
# 998    Chalupa  43.19
# 999    Chalupa  28.36
#
# [1000 rows x 2 columns]

# %%
df1.iloc[1:5,1:3]
# Out:
#    Gender          City
# 1    Male      Stamford
# 2    Male      New York
# 3  Female  Philadelphia
# 4  Female  Philadelphia

# %% [markdown]
# # Exploratory Data Analysis - Part 1

# %%
pd.set_option('display.max_columns', None) # see all columns

df_salary = pd.read_csv('https://raw.githubusercontent.com/renatomaaliw3/public_files/refs/heads/master/Data%20Sets/salaries.csv', index_col = 'Id')
df_salary.head(3)
# Out:
#       EmployeeName                                        JobTitle    BasePay  \
# Id
# 1   NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 2     GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 3   ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)  212739.13
#
#     OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# Id
# 1          0.00  400184.25       NaN  567595.43         567595.43  2011
# 2     245131.88  137811.38       NaN  538909.28         538909.28  2011
# 3     106088.18   16452.60       NaN  335279.91         335279.91  2011
#
#     Notes         Agency  Status
# Id
# 1     NaN  San Francisco     NaN
# 2     NaN  San Francisco     NaN
# 3     NaN  San Francisco     NaN

# %%
# Check how many entries

df_salary.info() # number of columns and number of row entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148654 entries, 1 to 148654
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   EmployeeName      148654 non-null  object
#  1   JobTitle          148654 non-null  object
#  2   BasePay           148045 non-null  float64
#  3   OvertimePay       148650 non-null  float64
#  4   OtherPay          148650 non-null  float64
#  5   Benefits          112491 non-null  float64
#  6   TotalPay          148654 non-null  float64
#  7   TotalPayBenefits  148654 non-null  float64
#  8   Year              148654 non-null  int64
#  9   Notes             0 non-null       float64
#  10  Agency            148654 non-null  object
#  11  Status            0 non-null       float64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 14.7+ MB

# %%
# What is the average base pay?

df_salary['BasePay'].mean()
# Out:
# 66325.4488404877

# %%
# What is the highest amount of OvertimePay in the dataset?

df_salary['OvertimePay'].max()
# Out:
# 245131.88

# %%
# What is the Job title of Joseph Driscoll?

df_salary[df_salary['EmployeeName'] == 'Joseph Driscoll']['JobTitle']
# Out:
# Id
# 36199    Captain, Fire Suppression
# Name: JobTitle, dtype: object

# %%
# How much does Joseph Driscoll make including benefits?

df_salary[df_salary['EmployeeName'] == 'Joseph Driscoll']['TotalPayBenefits']
# Out:
# Id
# 36199    331834.79
# Name: TotalPayBenefits, dtype: float64

# %%
# Who is the highest paid person including benefits?

df_salary[df_salary['TotalPayBenefits'] == df_salary['TotalPayBenefits'].max()][['EmployeeName', 'TotalPayBenefits']]
# Out:
#       EmployeeName  TotalPayBenefits
# Id
# 1   NATHANIEL FORD         567595.43

# %%
# Alternative

df_salary.sort_values(by = 'TotalPayBenefits', ascending = False)[['EmployeeName', 'TotalPayBenefits']].head(1)
# Out:
#       EmployeeName  TotalPayBenefits
# Id
# 1   NATHANIEL FORD         567595.43

# %%
# What was the average BasePay of all employees per year? (2011 - 2014)

df_salary[['Year', 'BasePay']].groupby('Year').mean()
# Out:
#            BasePay
# Year
# 2011  63595.956517
# 2012  65436.406857
# 2013  69630.030216
# 2014  66564.421924

# %%
# What was the average BasePay of all employees per year? (2011, 2013 only)

# df_filtered = df_salary.groupby('Year').mean()
# df_filtered = df_filtered.query("Year == 2011 | Year == 2013")
# df_filtered['BasePay']

df_salary[['Year', 'BasePay']].groupby('Year').mean().query('Year == 2011 | Year == 2013')
# Out:
#            BasePay
# Year
# 2011  63595.956517
# 2013  69630.030216

# %%
# How many unique job titles are there?

df_salary['JobTitle'].nunique()
# Out:
# 2159

# %%
# What are the top 3 most common jobs?

df_salary['JobTitle'].value_counts().head(3)
# Out:
# JobTitle
# Transit Operator    7036
# Special Nurse       4389
# Registered Nurse    3736
# Name: count, dtype: int64

# %%
# How many Job Titles were represented by only one person in 2013?

(df_salary[df_salary['Year'] == 2013]['JobTitle'].value_counts() == 1).sum()
# Out:
# 202

# %%
# How many people have the word 'Chief' in their job title? (Case will not matter, count 'chief' and 'Chief', etc.)

df_salary['JobTitle'].apply(lambda x: 'chief' in str(x).lower()).sum()
# Out:
# 627

# %%
# How many Employees has the last name 'Smith', case will not matter

df_salary[df_salary['EmployeeName'].str.lower().str.endswith('smith')]

# %%
# How many Employees has the last name 'Smith', case will not matter, with BasePay of >= 150000

# len(df_salary[df_salary['EmployeeName'].str.lower().str.endswith('smith')].query('BasePay >= 150000'))
df_salary[df_salary['EmployeeName'].str.lower().str.endswith('smith') & (df_salary['BasePay'] >= 150000)]
# Out:
#            EmployeeName                                           JobTitle  \
# Id
# 98          KEVIN SMITH                 BATTALION CHIEF, (FIRE DEPARTMENT)
# 111          MARK SMITH                                        ANESTHETIST
# 139         JESSE SMITH  CONFIDENTIAL CHIEF ATTORNEY II (CIVIL & CRIMINAL)
# 1517          JON SMITH                         ASSISTANT MEDICAL EXAMINER
# 36220        Mark Smith                                        Anesthetist
# 36229       Kevin Smith                     Battlion Chief, Fire Suppressi
# 36282       Jesse Smith                     Cfdntal Chf Atty 2,(Cvl&Crmnl)
# 37619     Bridget Smith                       Engineer/Architect Principal
# 38210       David Smith                                       Lieutenant 3
# 72981     Kevin W Smith                     Battalion Chief, Fire Suppress
# 73006      Mark A Smith                                        Anesthetist
# 73071     Jesse C Smith                     Cfdntal Chf Atty 2,(Cvl&Crmnl)
# 73924   Britton L Smith                          Captain, Fire Suppression
# 74431   Bridget B Smith                       Engineer/Architect Principal
# 75412      David  Smith                                       Lieutenant 3
# 75505     David E Smith                                Clinical Pharmacist
# 110574    Kevin W Smith                     Battalion Chief, Fire Suppress
# 110654    Jesse C Smith                     Cfdntal Chf Atty 2,(Cvl&Crmnl)
# 110729     Mark A Smith                                        Anesthetist
# 112444    David E Smith                                Clinical Pharmacist
# 112844  Bridget B Smith                       Engineer/Architect Principal
#
#           BasePay  OvertimePay  OtherPay  Benefits   TotalPay  \
# Id
# 98      168692.67     35402.71  22261.95       NaN  226357.33
# 111     206057.69      3431.01  10921.33       NaN  220410.03
# 139     213907.72         0.00   1080.96       NaN  214988.68
# 1517    153902.71         0.00   7019.05       NaN  160921.76
# 36220   221084.95      3892.42   9874.61  75463.40  234851.98
# 36229   176515.52     45860.99  27969.77  53182.45  250346.28
# 36282   214883.95         0.00   3008.00  65439.18  217891.95
# 37619   163253.60         0.00     60.00  52667.12  163313.60
# 38210   155320.05      4076.97   4954.45  39673.22  164351.47
# 72981   186236.47     47959.88  33067.83  57855.78  267264.18
# 73006   228250.31      6538.39  11259.84  65228.20  246048.54
# 73071   224277.50         0.00   1089.00  65587.32  225366.50
# 73924   155174.49     21392.93  11295.48  47883.09  187862.90
# 74431   177234.42         0.00      0.00  47949.02  177234.42
# 75412   155416.79         0.00   7989.11  42934.92  163405.90
# 75505   156503.00      2610.75    114.14  45513.90  159227.89
# 110574  177722.49     59117.49  29645.29  59909.13  266485.27
# 110654  221676.97         0.00      0.00  70840.72  221676.97
# 110729  205394.61      2211.25   8091.78  61808.17  215697.64
# 112444  160798.01      3490.06    246.80  49894.25  164534.87
# 112844  160370.09         0.00      0.00  46919.53  160370.09
#
#         TotalPayBenefits  Year  Notes         Agency  Status
# Id
# 98             226357.33  2011    NaN  San Francisco     NaN
# 111            220410.03  2011    NaN  San Francisco     NaN
# 139            214988.68  2011    NaN  San Francisco     NaN
# 1517           160921.76  2011    NaN  San Francisco     NaN
# 36220          310315.38  2012    NaN  San Francisco     NaN
# 36229          303528.73  2012    NaN  San Francisco     NaN
# 36282          283331.13  2012    NaN  San Francisco     NaN
# 37619          215980.72  2012    NaN  San Francisco     NaN
# 38210          204024.69  2012    NaN  San Francisco     NaN
# 72981          325119.96  2013    NaN  San Francisco     NaN
# 73006          311276.74  2013    NaN  San Francisco     NaN
# 73071          290953.82  2013    NaN  San Francisco     NaN
# 73924          235745.99  2013    NaN  San Francisco     NaN
# 74431          225183.44  2013    NaN  San Francisco     NaN
# 75412          206340.82  2013    NaN  San Francisco     NaN
# 75505          204741.79  2013    NaN  San Francisco     NaN
# 110574         326394.40  2014    NaN  San Francisco     NaN
# 110654         292517.69  2014    NaN  San Francisco     NaN
# 110729         277505.81  2014    NaN  San Francisco     NaN
# 112444         214429.12  2014    NaN  San Francisco     NaN
# 112844         207289.62  2014    NaN  San Francisco     NaN
