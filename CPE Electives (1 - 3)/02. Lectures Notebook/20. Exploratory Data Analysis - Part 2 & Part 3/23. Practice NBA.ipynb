# %% [markdown]
# # NBA Data

# %%
# Imports

import numpy as np
import pandas as pd

# %%
# Load Dataset

nba = pd.read_csv('https://raw.githubusercontent.com/renatomaaliw3/public_files/master/Data%20Sets/nba.csv')
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
# Check for missing data

nba.isnull().sum()
# Out:
# Name          1
# Team          1
# Position      8
# Height        7
# Weight        8
# College      14
# Salary      104
# dtype: int64

# %%
# Remove data with all column values of 'NaN'

nba = nba.dropna(how = 'all') # all column values with missing data
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
# Replace Salary with NaN with 0

nba['Salary'].fillna(0, inplace = True)
nba
# Out:
# <ipython-input-5-65645e86dfff>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba['Salary'].fillna(0, inplace = True)
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# ...

# %%
# Replace College with NaN with Uknown

nba['College'].fillna('Unknown', inplace = True)
nba
# Out:
# <ipython-input-6-35f9b4c43e4b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba['College'].fillna('Unknown', inplace = True)
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# ...

# %%
# Show actual rows with missing data

nba[nba.isnull().any(axis = 1)]
# Out:
#                 Name              Team Position Height  Weight  College  \
# 15      Miles Norris     Atlanta Hawks      NaN    NaN     NaN  Unknown
# 129    Jordan Walker  Dallas Mavericks      NaN    NaN     NaN  Unknown
# 134      Souley Boum    Denver Nuggets      NaN    NaN     NaN  Unknown
# 138  Armaan Franklin    Denver Nuggets      NaN    NaN     NaN  Unknown
# 299    Caleb Daniels        Miami Heat      NaN    NaN     NaN  Unknown
# 460   Toumani Camara      Phoenix Suns        F    6-8     NaN   Dayton
# 541     Kevin Obanor   Toronto Raptors      NaN    6-8   235.0  Unknown
# 564     Nick Ongenda         Utah Jazz      NaN    NaN     NaN  Unknown
#
#         Salary
# 15    559782.0
# 129  1119563.0
# 134  1119563.0
# 138  1119563.0
# 299  1119563.0
# 460  1119563.0
# 541  1119563.0
# 564  1119563.0

# %%
# Remove all data with NaN

nba.dropna(inplace = True)
nba
# Out:
# <ipython-input-8-bfceb4552f22>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba.dropna(inplace = True)
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# ...

# %%
# astype

nba['Salary'] = nba['Salary'].astype('int')
nba
# Out:
# <ipython-input-9-46414f8ef85a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba['Salary'] = nba['Salary'].astype('int')
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# ...

# %%
# Reset Index

nba.reset_index(drop = True, inplace = True)
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 578       Jordan Poole  Washington Wizards        G    6-4   194.0
# 579       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 580      Landry Shamet  Washington Wizards        G    6-4   190.0
# 581   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 582       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College    Salary
# 0        Villanova   4556983
# 1       Fenerbahce  18700000
# 2         Michigan   4094244
# 3      Elan Chalon  20616000
# ...

# %% [markdown]
# ## Data Extraction Practice

# %%
# 1. What is the average salary of NBA players

nba['Salary'].mean()
# Out:
# 7702340.79245283

# %%
# 2. Who are the top 3 highest paid player on the Golden State Warriors roster?

nba[nba['Team'] == 'Golden State Warriors'].sort_values(by = 'Salary', ascending = False).head(3)
# Out:
#               Name                   Team Position Height  Weight  \
# 171  Stephen Curry  Golden State Warriors        G    6-2   185.0
# 186  Klay Thompson  Golden State Warriors        G    6-6   220.0
# 181     Chris Paul  Golden State Warriors        G    6-0   175.0
#
#               College    Salary
# 171          Davidson  51915615
# 186  Washington State  43219440
# 181       Wake Forest  30800000

# %%
# 3. Who are the highest paid player for each team in the NBA, sort by Salary Descending?

nba.loc[nba.groupby('Team')['Salary'].idxmax()][['Team', 'Name', 'Salary']].sort_values('Salary', ascending = False)
# Out:
#                        Team                     Name    Salary
# 171   Golden State Warriors            Stephen Curry  51915615
# 455            Phoenix Suns             Kevin Durant  47649433
# 431      Philadelphia 76ers              Joel Embiid  47607350
# 141          Denver Nuggets             Nikola Jokic  47607350
# 257      Los Angeles Lakers             LeBron James  47607350
# 235    Los Angeles Clippers              Paul George  45640084
# 474  Portland Trail Blazers           Damian Lillard  45640084
# 311         Milwaukee Bucks    Giannis Antetokounmpo  45640084
# 292              Miami Heat             Jimmy Butler  45183960
# 339  Minnesota Timberwolves              Rudy Gobert  41000000
# 205         Houston Rockets            Fred VanVleet  40806300
# 16            Atlanta Hawks               Trae Young  40064220
# 112        Dallas Mavericks              Luka Doncic  40064220
# 82            Chicago Bulls              Zach LaVine  40064220
# ...

# %%
# 4. How many players are part of each Team?

nba.groupby('Team').count()['Name']
# Out:
# Team
# Atlanta Hawks             17
# Boston Celtics            18
# Brooklyn Nets             17
# Charlotte Hornets         20
# Chicago Bulls             19
# Cleveland Cavaliers       19
# Dallas Mavericks          22
# Denver Nuggets            20
# Detroit Pistons           19
# Golden State Warriors     17
# Houston Rockets           20
# Indiana Pacers            21
# Los Angeles Clippers      19
# Los Angeles Lakers        19
# Memphis Grizzlies         22
# Miami Heat                21
# Milwaukee Bucks           22
# Minnesota Timberwolves    19
# New Orleans Pelicans      16
# New York Knicks           21
# Oklahoma City Thunder     21
# Orlando Magic             18
# Philadelphia 76ers        21
# Phoenix Suns              19
# Portland Trail Blazers    17
# Sacramento Kings          18
# San Antonio Spurs         20
# Toronto Raptors           20
# Utah Jazz                 20
# Washington Wizards        21
# Name: Name, dtype: int64

# %%
# 5. Who are the players that have salaries between 20M to 40M in the Los Angeles Lakers and Los Angeles Clippers, in Salary descending order?

nba.query("(Salary >= 20000000 and Salary <= 60000000) and Team in ['Los Angeles Lakers', 'Los Angeles Clippers']").sort_values('Salary', ascending = False)
# Out:
#               Name                  Team Position Height  Weight  \
# 257   LeBron James    Los Angeles Lakers        F    6-9   250.0
# 235    Paul George  Los Angeles Clippers        F    6-8   220.0
# 237  Kawhi Leonard  Los Angeles Clippers        F    6-7   225.0
# 250  Anthony Davis    Los Angeles Lakers      F-C   6-10   253.0
#
#                           College    Salary
# 257  St. Vincent-St. Mary HS (OH)  47607350
# 235                  Fresno State  45640084
# 237               San Diego State  45640084
# 250                      Kentucky  40600080

# %%
# 6. The General Manager is looking for a G (Guard) with weight of 200 lbs. above with current salary of 10M and below

is_guard = nba['Position'] == 'G'
req_weight = nba['Weight'] == 200
req_salary = nba['Salary'] <= 10000000

nba[is_guard & req_weight & req_salary]
# Out:
#                   Name                    Team Position Height  Weight  \
# 64     Frank Ntilikina       Charlotte Hornets        G    6-4   200.0
# 74        Jevon Carter           Chicago Bulls        G    6-1   200.0
# 78         Ayo Dosunmu           Chicago Bulls        G    6-5   200.0
# 114         Josh Green        Dallas Mavericks        G    6-7   200.0
# 135        Andrew Funk          Denver Nuggets        G    6-5   200.0
# 151      Peyton Watson          Denver Nuggets        G    6-7   200.0
# 176        Cory Joseph   Golden State Warriors        G    6-3   200.0
# 246  Russell Westbrook    Los Angeles Clippers        G    6-3   200.0
# 283       Derrick Rose       Memphis Grizzlies        G    6-3   200.0
# 304    Josh Richardson              Miami Heat        G    6-6   200.0
# 348      Austin Rivers  Minnesota Timberwolves        G    6-4   200.0
# 412      Anthony Black           Orlando Magic        G    6-7   200.0
# ...

# %%
# 7. Who are the playes with 'State' instances in their College and current Team of Utah Jazz?

with_state = nba['College'].str.contains('State', case = False)
current_team = nba['Team'] == 'Utah Jazz'

nba[with_state & current_team]
# Out:
#                     Name       Team Position Height  Weight         College  \
# 548          Joey Hauser  Utah Jazz        F    6-9   230.0  Michigan State
# 550  Talen Horton-Tucker  Utah Jazz        G    6-4   234.0      Iowa State
# 559     Brice Sensabaugh  Utah Jazz        F    6-6   235.0      Ohio State
#
#        Salary
# 548    559782
# 550  11020000
# 559   2448600

# %%
# 8. Who are the players who entered the league from High School and has a salary of 30M and above

from_highschool = nba['College'].str.contains('HS', case = False)
req_salary = nba['Salary'] >= 20000000

nba[from_highschool & req_salary]
# Out:
#                 Name                    Team Position Height  Weight  \
# 257     LeBron James      Los Angeles Lakers        F    6-9   250.0
# 480  Anfernee Simons  Portland Trail Blazers        G    6-3   181.0
#
#                           College    Salary
# 257  St. Vincent-St. Mary HS (OH)  47607350
# 480             Edgewater HS (FL)  24107143

# %%
# 9. The team is looking for a pure Center (C) with weight of 250 lbs - 310 lbs and a Salary of 10M to 20M, Name in Ascending, Salary in Descending

req_pos = nba['Position'] == 'C'
req_weight = (nba['Weight'] >= 250) & (nba['Weight'] <= 310)
req_salary = (nba['Salary'] >= 10000000) & (nba['Salary'] >= 20000000)

nba[req_pos & req_weight & req_salary].sort_values(by = ['Name', 'Salary'], ascending = [True, False])
# Out:
#               Name                    Team Position Height  Weight  \
# 324    Brook Lopez         Milwaukee Bucks        C    7-1   282.0
# 3     Clint Capela           Atlanta Hawks        C   6-10   256.0
# 448  Deandre Ayton            Phoenix Suns        C    7-0   250.0
# 141   Nikola Jokic          Denver Nuggets        C   6-11   284.0
# 339    Rudy Gobert  Minnesota Timberwolves        C    7-1   258.0
#
#          College    Salary
# 324     Stanford  25000000
# 3    Elan Chalon  20616000
# 448      Arizona  32459438
# 141  Mega Basket  47607350
# 339       Cholet  41000000

# %%
# 10. Give me players that plays two-positions from the Dallas Mavericks and San Antonio Spurs, sort by Salar Descending and Weight Descending

req_pos = nba.query("~Position.isin(['C', 'F', 'G']) & (Team == 'Dallas Mavericks' or Team == 'San Antonio Spurs')")
req_pos.sort_values(by = ['Salary', 'Weight'], ascending = [False, False])
# Out:
#                       Name               Team Position Height  Weight  \
# 112            Luka Doncic   Dallas Mavericks      F-G    6-7   230.0
# 511         Keldon Johnson  San Antonio Spurs      F-G    6-5   220.0
# 520      Victor Wembanyama  San Antonio Spurs      F-C    7-4   210.0
# 506         Reggie Bullock  San Antonio Spurs      G-F    6-6   205.0
# 509           Zach Collins  San Antonio Spurs      F-C   6-11   250.0
# 519          Devin Vassell  San Antonio Spurs      G-F    6-5   200.0
# 126          Dwight Powell   Dallas Mavericks      F-C   6-10   240.0
# 503         Charles Bassey  San Antonio Spurs      C-F    6-9   230.0
# 513  Sandro Mamukelashvili  San Antonio Spurs      F-C   6-10   240.0
# 128           Joe Wieskamp   Dallas Mavericks      G-F    6-6   205.0
# 125            Theo Pinson   Dallas Mavericks      G-F    6-7   212.0
# 115       Tim Hardaway Jr.   Dallas Mavericks      G-F    6-5   205.0
#
#               College    Salary
# ...
